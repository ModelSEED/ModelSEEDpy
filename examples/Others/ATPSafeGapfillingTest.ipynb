# %%
import sys
import cobra
import cplex
import cobrakbase
#Put the path to ModelSEEDpy on your machine here
sys.path.append("/Users/chenry/code/ModelSEEDpy")
#import modelseedpy.fbapkg
from modelseedpy import MSPackageManager, FBAHelper, MSBuilder
# Out:
# cobrakbase 0.2.7

# %%
kbase_api = cobrakbase.KBaseAPI()
model = kbase_api.get_from_ws("",93541)
MMMedia = model = kbase_api.get_from_ws("Carbon-D-Glucose","KBaseMedia")
FBAHelper.set_objective_from_target_reaction(model, "bio2")
pkgmgr = MSPackageManager.get_pkg_mgr(model)
pkgmgr.getpkg("KBaseMediaPkg").build_package(MMMedia)
solution=model.optimize()
tests = [{"media":MMMedia,"is_max_threshold": True,"threshold":1.2*solution.objective_value}]
template = kbase_api.get_from_ws("GramNegModelTemplateV3","NewKBaseModelTemplates")
gfmodel = MSBuilder.gapfill_model(model,"bio1",template,MMMedia,tests)
FBAHelper.set_objective_from_target_reaction(gfmodel, "bio2")
gfpkgmgr = MSPackageManager.get_pkg_mgr(gfmodel)
gfpkgmgr.getpkg("KBaseMediaPkg").build_package(MMMedia)
gfsolution=gfmodel.optimize()
print(str(solution.objective_value)+" vs "+str(gfsolution.objective_value))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-9f8cc5863182> in <module>
#       3 modellist = kbase_api.ws_client.list_objects({
#       4     "ids":[93541],
# ----> 5     "type":"KBaseFBA.FBAModel"
#       6 })
#       7 #Iterate over the models and run FBA
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cobrakbase/Workspace/WorkspaceClient.py in list_objects(self, params, context)
#    3157         return self._client.call_method(
#    3158             'Workspace.list_objects',
# -> 3159             [params], self._service_ver, context)
#    3160
#    3161     def get_objectmeta(self, params, context=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cobrakbase/Workspace/baseclient.py in call_method(self, service_method, args, service_ver, context)
#     266         url = self._get_service_url(service_method, service_ver)
#     267         context = self._set_up_context(service_ver, context)
# --> 268         return self._call(url, service_method, args, context)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/cobrakbase/Workspace/baseclient.py in _call(self, url, method, params, context)
#     187                 raise ServerError('Unknown', 0, ret.text)
#     188         if not ret.ok:
# --> 189             ret.raise_for_status()
#     190         resp = ret.json()
#     191         if 'result' not in resp:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     938
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#     942     def close(self):
#
# HTTPError: 403 Client Error: Forbidden for url: https://www.kbase.us/
