# %% [markdown]
# # Define the models

# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the models
import cobrakbase
token = '4GBQCLKV4Z7OOJZMI43UB27QIPGS353I'
kbase_api = cobrakbase.KBaseAPI(token)
model1 = kbase_api.get_from_ws("iML1515",76994)
# model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
# Out:
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd11416_c0]: not found

# %% [markdown]
# # Execute the simulation

# %%
# %run ../../modelseedpy/fbapkg/dfbapkg.py

# define in the initial conditions
modelseed_db_path = os.path.join('..', '..', '..', 'ModelSEEDDatabase')
initial_concentrations_M = {
    "cpd00002":200, 
    "cpd00008":100
}
total_time = 5
timestep = 1

# execute the package
dfba = dFBAPkg(model1, modelseed_db_path, verbose = False)
conc, fluxes = dfba.simulate('model_kinetics.json', initial_concentrations_M, total_time, timestep, labeled_plots = False, export = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\Andrew Freiburger\AppData\Local\Temp\ipykernel_25420\1511748022.py in <module>
#      11
#      12 # execute the package
# ---> 13 dfba = dFBA(model1, modelseed_db_path, verbose = False)
#      14 conc, fluxes = dfba.simulate('model_kinetics.json', initial_concentrations_M, total_time, timestep, labeled_plots = False, export = False)
#
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\fbapkg\dfbapkg.py in __init__(self, model, modelseed_db_path, solver, warnings, verbose, printing, jupyter)
#      73         for met in self.model.metabolites:
#      74             self.met_ids.append(met.id)
# ---> 75             self.met_names.append(self.compound_id[met.id])
#      76
#      77     def __find_data_match(self,
#
# KeyError: 'cpd01911_c0'
