# %% [markdown]
# # Import the modules

# %%
# import the general modules
import cplex
import sys

# import kbase
import os
# os.environ["HOME"] = 'C:\\Users\\Andrew Freiburger\\Dropbox\\My PC (DESKTOP-M302P50)\\Documents\\UVic Civil Engineering\\Internships\\Agronne\\cobrakbase'
import cobrakbase
token = 'JOSNYJGASTV5BGELWQTUSATE4TNHZ66U'
kbase = cobrakbase.KBaseAPI(token)

# local ModelSEED database path
modelseed_db_path = '../../../ModelSEEDDatabase'
# Out:
# cobrakbase 0.2.8

# %% [markdown]
# # SimpleThermo dgbin parameterization

# %% [markdown]
# ## sans dgbin

# %%
# define the example individual model, with integer charges, and associated API media package
model = kbase.get_from_ws('e_coli_core.kb', 94253)
for metabolite in model.metabolites:
    try:
        metabolite.charge = int(metabolite.charge)
    except:
        print(metabolite, metabolite.charge)
        metabolite.charge = None
model.solver = 'optlang-cplex'

# apply the simple thermodynamic constraints 
# %run ../../modelseedpy/fbapkg/simplethermopkg.py
stp = SimpleThermoPkg(model)
stp.build_package({"dgbin": False})

# execute the model
print(model.objective)
model.summary()
# Out:
# Minimize
# -59.81*cpd00001_c0_potential - 59.81*cpd00002_c0_potential - 3.547*cpd00003_c0_potential + 3.547*cpd00004_c0_potential - 13.0279*cpd00005_c0_potential + 13.0279*cpd00006_c0_potential + 59.81*cpd00008_c0_potential + 59.81*cpd00009_c0_potential + 3.7478*cpd00010_c0_potential - 2.8328*cpd00020_c0_potential - 3.7478*cpd00022_c0_potential - 4.9414*cpd00023_c0_potential + 4.1182*cpd00024_c0_potential - 1.7867*cpd00032_c0_potential - 0.2557*cpd00053_c0_potential - 0.5191*cpd00061_c0_potential + 59.81*cpd00067_c0_potential - 0.0709*cpd00072_c0_potential - 0.205*cpd00079_c0_potential - 0.8977*cpd00101_c0_potential - 0.129*cpd00102_c0_potential - 1.496*cpd00169_c0_potential - 0.361*cpd00236_c0_potential
# <h3>Objective</h3><p>nan Expression = nan</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ## Constrain the model with dgbin

# %%
# define the example individual model, with integer charges, and associated API media package
model = kbase.get_from_ws('e_coli_core.kb', 94253)
for metabolite in model.metabolites:
    try:
        metabolite.charge = int(metabolite.charge)
    except:
        print(metabolite, metabolite.charge)
        metabolite.charge = None
model.solver = 'optlang-cplex'

stp.clear()
# apply the simple thermodynamic constraints 
stp = SimpleThermoPkg(model)
stp.build_package({"dgbin": True})

# export the constrained LP file 
with open('SimpleThermo_dgbin.lp', 'w') as out:
    out.write(str(model.solver))
    
# execute the model
print(model.objective)
model.summary()
# Out:
# optimal status for rxn00549_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05312_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00247_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00786_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08865_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01200_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08525_c0
# --> ERROR: The simulation lack a solution.
# optimal status for FRD7_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00545_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09270_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00173_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08288_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00459_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00083_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00097_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn32421_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00154_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn19316_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00187_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00558_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05319_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00747_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05468_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn35242_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08535_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01115_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00225_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00500_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08350_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn20162_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01333_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn30674_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01100_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn39085_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08173_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00285_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00161_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00543_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05297_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05467_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05488_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00085_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00062_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn34258_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00171_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05559_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09272_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00604_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00159_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08972_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08542_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01106_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00198_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01476_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00781_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09295_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00785_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08032_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00189_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00336_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00147_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09269_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00248_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00974_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05493_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00777_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08094_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05226_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05155_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08427_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00184_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05469_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn32587_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01116_c0
# --> ERROR: The simulation lack a solution.
# optimal status for bio1
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00549_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05312_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00247_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00786_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08865_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01200_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08525_c0
# --> ERROR: The simulation lack a solution.
# optimal status for FRD7_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00545_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09270_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00173_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08288_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00459_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00083_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00097_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn32421_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00154_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn19316_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00187_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00558_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05319_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00747_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05468_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn35242_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08535_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01115_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00225_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00500_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08350_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn20162_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01333_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn30674_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01100_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn39085_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08173_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00285_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00161_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00543_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05297_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05467_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05488_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00085_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00062_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn34258_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00171_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05559_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09272_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00604_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00159_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08972_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08542_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01106_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00198_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01476_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00781_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09295_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00785_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08032_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00189_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00336_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00147_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09269_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00248_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00974_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05493_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00777_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08094_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05226_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05155_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08427_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00184_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05469_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn32587_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01116_c0
# --> ERROR: The simulation lack a solution.
# optimal status for bio1
# --> ERROR: The simulation lack a solution.
# Maximize
# 0
# <h3>Objective</h3><p>nan Expression = nan</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# # FullThermo infeasibility parameterization

# %% [markdown]
# ## sans dgbin

# %%
# define the example individual model, with integer charges, and associated API media package
model = kbase.get_from_ws('e_coli_core.kb', 94253)
for metabolite in model.metabolites:
    try:
        metabolite.charge = int(metabolite.charge)
    except:
        print(metabolite, metabolite.charge)
        metabolite.charge = None
model.solver = 'optlang-cplex'

# import the FullThermo package
# %run ../../modelseedpy/fbapkg/fullthermopkg.py
ftp = FullThermoPkg(model)
ftp.build_package({"dgbin": False, 'modelseed_path':modelseed_db_path})

# execute the model
print(model.objective)
model.summary()
# Out:
# Minimize
# -59.81*cpd00001_c0_potential - 59.81*cpd00002_c0_potential - 3.547*cpd00003_c0_potential + 3.547*cpd00004_c0_potential - 13.0279*cpd00005_c0_potential + 13.0279*cpd00006_c0_potential + 59.81*cpd00008_c0_potential + 59.81*cpd00009_c0_potential + 3.7478*cpd00010_c0_potential - 2.8328*cpd00020_c0_potential - 3.7478*cpd00022_c0_potential - 4.9414*cpd00023_c0_potential + 4.1182*cpd00024_c0_potential - 1.7867*cpd00032_c0_potential - 0.2557*cpd00053_c0_potential - 0.5191*cpd00061_c0_potential + 59.81*cpd00067_c0_potential - 0.0709*cpd00072_c0_potential - 0.205*cpd00079_c0_potential - 0.8977*cpd00101_c0_potential - 0.129*cpd00102_c0_potential - 1.496*cpd00169_c0_potential - 0.361*cpd00236_c0_potential
# <h3>Objective</h3><p>nan Expression = nan</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ## with dgbin

# %%
# define the example individual model, with integer charges, and associated API media package
model = kbase.get_from_ws('e_coli_core.kb', 94253)
for metabolite in model.metabolites:
    try:
        metabolite.charge = int(metabolite.charge)
    except:
        print(metabolite, metabolite.charge)
        metabolite.charge = None
model.solver = 'optlang-cplex'

# import the FullThermo package
# %run ../../modelseedpy/fbapkg/fullthermopkg.py
ftp.clear()
ftp = FullThermoPkg(model)
ftp.build_package({"dgbin": True, 'modelseed_path':modelseed_db_path})

# export the constrained LP file 
with open('FullThermo_dgbin.lp', 'w') as out:
    out.write(str(model.solver))
    
# execute the model
print(model.objective)
model.summary()
# Out:
# optimal status for rxn00549_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05312_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00247_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00786_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08865_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01200_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08525_c0
# --> ERROR: The simulation lack a solution.
# optimal status for FRD7_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00545_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09270_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00173_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08288_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00459_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00083_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00097_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn32421_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00154_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn19316_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00187_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00558_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05319_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00747_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05468_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn35242_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08535_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01115_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00225_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00500_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08350_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn20162_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01333_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn30674_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01100_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn39085_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08173_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00285_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00161_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00543_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05297_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05467_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05488_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00085_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00062_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn34258_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00171_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05559_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09272_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00604_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00159_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08972_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08542_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01106_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00198_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01476_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00781_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09295_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00785_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08032_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00189_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00336_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00147_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09269_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00248_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00974_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05493_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00777_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08094_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05226_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05155_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08427_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00184_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05469_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn32587_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01116_c0
# --> ERROR: The simulation lack a solution.
# optimal status for bio1
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00549_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05312_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00247_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00786_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08865_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01200_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08525_c0
# --> ERROR: The simulation lack a solution.
# optimal status for FRD7_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00545_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09270_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00173_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08288_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00459_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00083_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00097_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn32421_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00154_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn19316_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00187_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00558_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05319_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00747_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05468_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn35242_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08535_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01115_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00225_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00500_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08350_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn20162_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01333_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn30674_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01100_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn39085_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08173_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00285_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00161_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00543_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05297_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05467_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05488_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00085_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00062_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn34258_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00171_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05559_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09272_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00604_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00159_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08972_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08542_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01106_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00198_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01476_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00781_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09295_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00785_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08032_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00189_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00336_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00147_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn09269_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00248_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00974_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05493_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00777_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08094_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05226_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05155_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn08427_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn00184_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn05469_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn32587_c0
# --> ERROR: The simulation lack a solution.
# optimal status for rxn01116_c0
# --> ERROR: The simulation lack a solution.
# optimal status for bio1
# --> ERROR: The simulation lack a solution.
# Maximize
# 0
# <h3>Objective</h3><p>nan Expression = nan</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# # Brainstorming

# %%
# for reaction in model.reactions:
#     if not reaction.id[:3] == 'EX_':
#         print(model.solver.status)
#         stp.variables['dgbinF'][reaction.id]
# # dir(stp.variables['dgbinF'][reaction.id].primal)
