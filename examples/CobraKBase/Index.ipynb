# %% [markdown]
# ![ModelSEEDpy](../images/ms-logo-horizontal.png)

# %% [markdown]
# Back to the main [Index](../Index.ipynb)

# %% [markdown]
# # CobraKBase

# %% [markdown]
# CobraKBase offers an API for accessing KBase objects, particularly models, as Cobrapy objects.
#
# ![image](ecology_tools.png)

# %% [markdown]
# # Installation instructions

# %% [markdown]
# git clone https://github.com/ModelSEED/ModelSEEDpy.git
#
# pip install ModelSEEDpy or cd <ModelSEEDpy repository folder> and pip install .
#
# git clone https://github.com/Fxe/cobrakbase.git (cobrakbase depends on ModelSEEDpy!!)
#
# pip install cobrakbase or cd <cobrakbase repository folder> and pip install .
#
# echo "|KBase token|" > ~/.kbase/token

# %% [markdown]
# ## Loading cobrapy model from KBase

# %%
sys.path.append("/Users/chenry/code/ModelSEEDpy")
sys.path.append("/Users/chenry/code/cobrakbase")
import sys
import json
import cobra
import cobrakbase
from modelseedpy import MSPackageManager, MSGrowthPhenotypes
kbase_api = cobrakbase.KBaseAPI()
#Objects can be pulled from KBase by name and workspace ID
model = kbase_api.get_from_ws("85963.7.fbamodel",117872)

# %% [markdown]
# # Loading media from KBase

# %%
#Pulling a media object
media = kbase_api.get_from_ws("Carbon-D-Glucose",117872)
#Using KBase media to constrain exchange reactions in model
pkgmgr = MSPackageManager.get_pkg_mgr(model,1)
pkgmgr.getpkg("KBaseMediaPkg",1).build_package(media, default_uptake=0, default_excretion=1000)

# %% [markdown]
# # Running flux balance analysis with CobraPy

# %%
#Setting objective to biomass reaction
model.objective = "bio1"
#Running FBA
solution = model.optimize()
solution
# Out:
# <Solution 0.495 at 0x7fee8b6c1c50>

# %% [markdown]
# # Simulating biolog

# %%
import pandas as pd
from IPython.display import HTML
kbpheno = kbase_api.get_object("85963.7.biolog", 114100)
biolog = MSGrowthPhenotypes.from_kbase_object(kbpheno,kbase_api)
output = biolog.simulate_phenotypes(model,"bio1",True)
HTML(output["details"].to_html(render_links=True, escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Phenotype</th>
#       <th>Observed growth</th>
#       <th>Simulated growth</th>
#       <th>Class</th>
#       <th>Transports missing</th>
#       <th>Gapfilled reactions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>D-Trehalose</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>FN</td>
#       <td></td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>N-Acetyl-b-D-Mannosamine</td>
#       <td>0.0</td>
#       <td>0.000000</td>
#       <td>CN</td>
#       <td></td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Dextrin</td>
#       <td>1.0</td>
#       <td>0.000000</td>
#       <td>FN</td>
#       <td></td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>a-Hydroxy-Butyric-Acid</td>
#       <td>1.0</td>
#       <td>0.000000</td>
# ...

# %% [markdown]
# # Listing workspace contents

# %%
genomes = kbase_api.list_objects(114100, object_type="KBaseGenomes.Genome", include_metadata=True)
for genome in genomes:
    print(genome[1])
    break
# Out:
# 149698.22

# %% [markdown]
# # Pulling other KBase objects
