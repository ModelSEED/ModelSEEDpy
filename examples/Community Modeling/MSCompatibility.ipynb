# %% [markdown]
# # Load the models

# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the models
import cobrakbase
token = 'WE6CHYRDTJSGOHFIDGPE7WYFT6PRPXJL'
kbase_api = cobrakbase.KBaseAPI(token)
model1 = kbase_api.get_from_ws("iML1515",76994)
model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
# Out:
# cobrakbase 0.2.8
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd11416_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found

# %% [markdown]
# # Align exchange reactions

# %%
# %run ../../modelseedpy/core/mscompatibility.py
mscompat = MSCompatibility(modelseed_db_path = os.path.join('..', '..', '..', 'ModelSEEDDatabase'))

models = [model1, model2]
# model1
before_model_rxns = after_model_rxns = []
for model in models:
    for rxn in model.reactions:
        before_model_rxns.append(rxn.reaction)
    if 'cpd00609_c0' in model.metabolites:
        print('The metabolite is in model', models.index(model))

models = mscompat.correct_exchanges(models, 'output.json')

print('\n\n')
for model in models:
    for rxn in model.reactions:
        after_model_rxns.append(rxn.reaction)
    if 'cpd00609_c0' in model.metabolites:
        print('The metabolite is in model', models.index(model))
        
for new_rxn in after_model_rxns:
    if new_rxn not in before_model_rxns:
        print('new rxn\t',  new_rxn, 'old rxn\t', before_model_rxns[after_model_rxns.index(new_rxn)])
# Out:
# The metabolite is in model 0
# The metabolite is in model 1
#
#
# {'original': {'id': 'r293', 'name': 'Fe2+'},
#  'new': {'id': 'cpd10515', 'name': 'Fe2+'},
#  'justification': 'The r293 and cpd10515 distinction is incompatible.'}
# {'model0_id': 'cpd10515_e0', 'model0_met': <ModelCompound cpd10515_e0 at 0x206f0d70c70>, 'model1_id': 'r293_e0', 'model1_met': <ModelCompound cpd10515 at 0x206ef8f2850>}
#
#
#
# The metabolite is in model 0
# The metabolite is in model 1

# %% [markdown]
# ## Standardize the models

# %%
# %run ../../modelseedpy/core/mscompatibility.py

model1 = kbase_api.get_from_ws("iML1515",76994)
model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
mscompat = MSCompatibility(modelseed_db_path = os.path.join('..', '..', '..', 'ModelSEEDDatabase'))


models = [model1, model2]
# model1
before_model_rxns = after_model_rxns = []
for model in models:
    for rxn in model.reactions:
        before_model_rxns.append(rxn.reaction)
    if 'cpd00609_c0' in model.metabolites:
        print('The metabolite is in model', models.index(model))

models = mscompat.standardize_MSD(models, output_path = 'standardized_output.txt')

for model in models:
    for rxn in model.reactions:
        after_model_rxns.append(rxn.reaction)
    if 'cpd00609_c0' in model.metabolites:
        print('The metabolite is in model', models.index(model))
        
for new_rxn in after_model_rxns:
    if new_rxn not in before_model_rxns:
        print('new rxn\t',  new_rxn, 'old rxn\t', before_model_rxns[after_model_rxns.index(new_rxn)])
# Out:
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd11416_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# The metabolite is in model 0
# The metabolite is in model 1
#
#
# {'original': {'id': 'mchtbs6p-c',
#               'name': "N-monoacetylchitobiose 6'-phosphate"},
#  'new': {'id': 'cpd33279', 'name': "N-monoacetylchitobiose 6'-phosphate"},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'id': 'bmoco-c', 'name': 'Bis-molybdenum cofactor'},
#  'new': {'id': 'cpd19503', 'name': 'Molybdenum cofactor'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'id': 'metsox-S-L-e', 'name': 'L-Methionine Sulfoxide'},
#  'new': {'id': 'cpd15498', 'name': 'L-Methionine Sulfoxide'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'cpd11421_c0 + metsox-S-L-c_c0 --> cpd00001_c0 + '
#                           'cpd00060_c0 + cpd11420_c0'},
#  'new': {'reaction': 'cpd11421_c0 + cpd15498 --> cpd00001_c0 + cpd00060_c0 + '
#                      'cpd11420_c0'},
#  'justification': 'The non-ModelSEED ID metsox-S-L-c_c0 in this reaction '
#                   '(METSOXR1_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00001_c0 + cpd00002_c0 + metsox-S-L-p_p0 --> '
#                           'cpd00008_c0 + cpd00009_c0 + cpd00067_c0 + '
#                           'metsox-S-L-c_c0'},
#  'new': {'reaction': 'cpd00001_c0 + cpd00002_c0 + metsox-S-L-p_p0 --> '
#                      'cpd00008_c0 + cpd00009_c0 + cpd00067_c0 + cpd15498'},
#  'justification': 'The non-ModelSEED ID metsox-S-L-c_c0 in this reaction '
#                   '(METSOX1abcpp_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00025_c0 + cpd00060_c0 --> cpd00001_c0 + '
#                           'metsox-S-L-c_c0'},
#  'new': {'reaction': 'cpd00025_c0 + cpd00060_c0 --> cpd00001_c0 + cpd15498'},
#  'justification': 'The non-ModelSEED ID metsox-S-L-c_c0 in this reaction '
#                   '(METOX1s_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd15498 <=> metsox-S-L-p_p0'},
#  'new': {'reaction': 'cpd15498 <=> cpd15498'},
#  'justification': 'The non-ModelSEED ID metsox-S-L-p_p0 in this reaction '
#                   '(METSOX1tex_e0) must be replaced.'}
#
#
# {'original': {'id': 'sq-p', 'name': 'Sulphoquinovose'},
#  'new': {'id': 'cpd32553', 'name': ''},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'cpd00058_c0 + cpd19505_c0 + 2.0 moadcosh-c_c0 --> '
#                           '5.0 cpd00067_c0 + cpd03520_c0 + 2.0 moadcoo-c_c0'},
#  'new': {'reaction': 'cpd00058_c0 + cpd19505_c0 + 2.0 moadcosh-c_c0 --> 5.0 '
#                      'cpd00067_c0 + cpd03520_c0 + 2.0 cpd32553'},
#  'justification': 'The non-ModelSEED ID moadcoo-c_c0 in this reaction '
#                   '(MPTS_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00002_c0 + cpd00067_c0 + moadcoo-c_c0 --> '
#                           'cpd00012_c0 + moadamp-c_c0'},
#  'new': {'reaction': 'cpd00002_c0 + cpd00067_c0 + cpd32553 --> cpd00012_c0 + '
#                      'moadamp-c_c0'},
#  'justification': 'The non-ModelSEED ID moadcoo-c_c0 in this reaction '
#                   '(MPTSS_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00004_c0 + iscssh-c_c0 + moadamp-c_c0 --> '
#                           'cpd00003_c0 + cpd00018_c0 + iscs-c_c0 + '
#                           'moadcosh-c_c0'},
#  'new': {'reaction': 'cpd00004_c0 + iscssh-c_c0 + moadamp-c_c0 --> cpd00003_c0 '
#                      '+ cpd00018_c0 + cpd32553 + moadcosh-c_c0'},
#  'justification': 'The non-ModelSEED ID iscs-c_c0 in this reaction '
#                   '(MOADSUx_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 iscssh-c_c0 + '
#                           'iscu-c_c0 --> cpd00015_c0 + 6.0 cpd00067_c0 + 2.0 '
#                           'iscs-c_c0 + iscu-2fe2s-c_c0'},
#  'new': {'reaction': 'cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 iscssh-c_c0 + '
#                      'iscu-c_c0 --> cpd00015_c0 + 6.0 cpd00067_c0 + 2.0 '
#                      'cpd32553 + iscu-2fe2s-c_c0'},
#  'justification': 'The non-ModelSEED ID iscs-c_c0 in this reaction '
#                   '(I2FE2SS_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 iscssh-c_c0 + '
#                           'iscu-2fe2s-c_c0 --> cpd00015_c0 + 6.0 cpd00067_c0 + '
#                           '2.0 iscs-c_c0 + iscu-2fe2s2-c_c0'},
#  'new': {'reaction': 'cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 iscssh-c_c0 + '
#                      'iscu-2fe2s-c_c0 --> cpd00015_c0 + 6.0 cpd00067_c0 + 2.0 '
#                      'cpd32553 + iscu-2fe2s2-c_c0'},
#  'justification': 'The non-ModelSEED ID iscs-c_c0 in this reaction '
#                   '(I2FE2SS2_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00002_c0 + cpd00005_c0 + cpd00067_c0 + '
#                           'cpd08289_c0 + cpd14545_c0 + iscssh-c_c0 --> 2.0 '
#                           'cpd00001_c0 + cpd00006_c0 + cpd00011_c0 + '
#                           'cpd00012_c0 + cpd00018_c0 + cpd02654_c0 + '
#                           'iscs-c_c0'},
#  'new': {'reaction': 'cpd00002_c0 + cpd00005_c0 + cpd00067_c0 + cpd08289_c0 + '
#                      'cpd14545_c0 + iscssh-c_c0 --> 2.0 cpd00001_c0 + '
#                      'cpd00006_c0 + cpd00011_c0 + cpd00012_c0 + cpd00018_c0 + '
#                      'cpd02654_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID iscs-c_c0 in this reaction '
#                   '(THZPSN3_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00084_c0 + iscs-c_c0 --> cpd00035_c0 + '
#                           'iscssh-c_c0'},
#  'new': {'reaction': 'cpd00084_c0 + cpd32553 --> cpd00035_c0 + iscssh-c_c0'},
#  'justification': 'The non-ModelSEED ID iscs-c_c0 in this reaction (ICYSDS_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': '2fe1s-c_c0 + iscssh-c_c0 + iscu-c_c0 --> 4.0 '
#                           'cpd00067_c0 + iscs-c_c0 + iscu-2fe2s-c_c0'},
#  'new': {'reaction': '2fe1s-c_c0 + iscssh-c_c0 + iscu-c_c0 --> 4.0 cpd00067_c0 '
#                      '+ cpd32553 + iscu-2fe2s-c_c0'},
#  'justification': 'The non-ModelSEED ID iscs-c_c0 in this reaction '
#                   '(I2FE2SR_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'sq-e_e0 <=> cpd32553'},
#  'new': {'reaction': 'cpd32553 <=> cpd32553'},
#  'justification': 'The non-ModelSEED ID sq-e_e0 in this reaction (SQtex_e0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'sq-e_e0 <=> '},
#  'new': {'reaction': 'cpd32553 <=> '},
#  'justification': 'The non-ModelSEED ID sq-e_e0 in this reaction (EX_sq-e_e0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'cpd32553 --> sq-c_c0'},
#  'new': {'reaction': 'cpd32553 --> cpd32553'},
#  'justification': 'The non-ModelSEED ID sq-c_c0 in this reaction (SQtr_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'sq-c_c0 --> sf-c_c0'},
#  'new': {'reaction': 'cpd32553 --> sf-c_c0'},
#  'justification': 'The non-ModelSEED ID sq-c_c0 in this reaction (SQVOSI_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00001_c0 + sqg-c_c0 --> cpd00100_c0 + sq-c_c0'},
#  'new': {'reaction': 'cpd00001_c0 + sqg-c_c0 --> cpd00100_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID sq-c_c0 in this reaction (SQGH_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'id': 'cpd00609', 'name': 'D-Glucarate_p0'},
#  'new': {'id': 'cpd00571', 'name': 'D-Glucarate'},
#  'justification': 'The cpd00609 and cpd00571 distinction is incompatible.'}
#
#
# {'original': {'reaction': 'cpd00067_p0 + cpd00571 <=> cpd00067_c0 + '
#                           'cpd00609_c0'},
#  'new': {'reaction': 'cpd00067_p0 + cpd00571 <=> cpd00067_c0 + cpd00571'},
#  'justification': 'The non-ModelSEED ID cpd00609_c0 in this reaction '
#                   '(GLCRt2rpp_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00609_c0 --> cpd00001_c0 + cpd00515_c0'},
#  'new': {'reaction': 'cpd00571 --> cpd00001_c0 + cpd00515_c0'},
#  'justification': 'The non-ModelSEED ID cpd00609_c0 in this reaction '
#                   '(rxn01989_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00609_e0 <=> '},
#  'new': {'reaction': 'cpd00571 <=> '},
#  'justification': 'The non-ModelSEED ID cpd00609_e0 in this reaction '
#                   '(EX_cpd00609_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00609_e0 <=> cpd00571'},
#  'new': {'reaction': 'cpd00571 <=> cpd00571'},
#  'justification': 'The non-ModelSEED ID cpd00609_e0 in this reaction '
#                   '(GLCRtex_e0) must be replaced.'}
#
#
# {'original': {'id': 'cpd19046',
#               'name': '(R)-2,3-Dihydroxy-3-methylpentanoate_c0'},
#  'new': {'id': 'cpd02535', 'name': '(R)-2,3-Dihydroxy-3-methylpentanoate'},
#  'justification': 'The cpd19046 and cpd02535 distinction is incompatible.'}
#
#
# {'original': {'reaction': 'sfp-c_c0 --> cpd00095_c0 + sla-c_c0'},
#  'new': {'reaction': 'sfp-c_c0 --> cpd00095_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID sla-c_c0 in this reaction (6D6SPA_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00004_c0 + cpd00067_c0 + sla-c_c0 --> '
#                           'cpd00003_c0 + dhps-c_c0'},
#  'new': {'reaction': 'cpd00004_c0 + cpd00067_c0 + cpd32553 --> cpd00003_c0 + '
#                      'dhps-c_c0'},
#  'justification': 'The non-ModelSEED ID sla-c_c0 in this reaction (3SLAR_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'id': '2hptcl-c',
#               'name': '2-hydroxycyclohepta-1,4,6-triene-1-carboxylate'},
#  'new': {'id': 'cpd31397',
#          'name': '2-hydroxycyclohepta-1,4,6-triene-1-carboxylate'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'cpd00052_c0 + 2.0 cpd00067_c0 + 2.0 cpd15465_c0 --> '
#                           'cpd00001_c0 + cpd00356_c0 + 2.0 flxso-c_c0'},
#  'new': {'reaction': 'cpd00052_c0 + 2.0 cpd00067_c0 + 2.0 cpd15465_c0 --> '
#                      'cpd00001_c0 + cpd00356_c0 + 2.0 cpd32553'},
#  'justification': 'The non-ModelSEED ID flxso-c_c0 in this reaction '
#                   '(RNTR3c2_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00038_c0 + 2.0 cpd00067_c0 + 2.0 cpd15465_c0 --> '
#                           'cpd00001_c0 + cpd00241_c0 + 2.0 flxso-c_c0'},
#  'new': {'reaction': 'cpd00038_c0 + 2.0 cpd00067_c0 + 2.0 cpd15465_c0 --> '
#                      'cpd00001_c0 + cpd00241_c0 + 2.0 cpd32553'},
#  'justification': 'The non-ModelSEED ID flxso-c_c0 in this reaction '
#                   '(RNTR2c2_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00067_c0 + cpd08301_c0 + 2.0 cpd15465_c0 --> '
#                           'cpd00001_c0 + cpd08615_c0 + 2.0 flxso-c_c0'},
#  'new': {'reaction': 'cpd00067_c0 + cpd08301_c0 + 2.0 cpd15465_c0 --> '
#                      'cpd00001_c0 + cpd08615_c0 + 2.0 cpd32553'},
#  'justification': 'The non-ModelSEED ID flxso-c_c0 in this reaction '
#                   '(MECDPDH5_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00005_c0 + 2.0 flxso-c_c0 --> cpd00006_c0 + '
#                           'cpd00067_c0 + 2.0 cpd15465_c0'},
#  'new': {'reaction': 'cpd00005_c0 + 2.0 cpd32553 --> cpd00006_c0 + cpd00067_c0 '
#                      '+ 2.0 cpd15465_c0'},
#  'justification': 'The non-ModelSEED ID flxso-c_c0 in this reaction (FLDR2_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00010_c0 + cpd00020_c0 + 2.0 flxso-c_c0 <=> '
#                           'cpd00011_c0 + cpd00022_c0 + cpd00067_c0 + 2.0 '
#                           'cpd15465_c0'},
#  'new': {'reaction': 'cpd00010_c0 + cpd00020_c0 + 2.0 cpd32553 <=> cpd00011_c0 '
#                      '+ cpd00022_c0 + cpd00067_c0 + 2.0 cpd15465_c0'},
#  'justification': 'The non-ModelSEED ID flxso-c_c0 in this reaction (POR5_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00002_c0 + 2.0 cpd00067_c0 + 2.0 cpd15465_c0 --> '
#                           'cpd00001_c0 + cpd00115_c0 + 2.0 flxso-c_c0'},
#  'new': {'reaction': 'cpd00002_c0 + 2.0 cpd00067_c0 + 2.0 cpd15465_c0 --> '
#                      'cpd00001_c0 + cpd00115_c0 + 2.0 cpd32553'},
#  'justification': 'The non-ModelSEED ID flxso-c_c0 in this reaction '
#                   '(RNTR1c2_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00062_c0 + 2.0 cpd00067_c0 + 2.0 cpd15465_c0 --> '
#                           'cpd00001_c0 + cpd00358_c0 + 2.0 flxso-c_c0'},
#  'new': {'reaction': 'cpd00062_c0 + 2.0 cpd00067_c0 + 2.0 cpd15465_c0 --> '
#                      'cpd00001_c0 + cpd00358_c0 + 2.0 cpd32553'},
#  'justification': 'The non-ModelSEED ID flxso-c_c0 in this reaction '
#                   '(RNTR4c2_c0) must be replaced.'}
#
#
# {'original': {'id': 'uaagmda-c',
#               'name': 'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-ala-D-glu-meso-2,6-diaminopimeloyl-D-ala-D-ala'},
#  'new': {'id': 'cpd22495',
#          'name': 'Undecaprenyl-diphospho-N-acetylmuramoyl-(N-acetylglucosamine)-L-ala-D-glu-meso-2,6-diaminopimeloyl-D-ala-D-ala'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'cpd00001_c0 + cpd00002_c0 + cpd00982_c0 + 2.0 '
#                           'cpd10515_c0 + sufbcd-c_c0 + 2.0 sufsesh-c_c0 --> '
#                           'cpd00008_c0 + cpd00009_c0 + cpd00015_c0 + 7.0 '
#                           'cpd00067_c0 + sufbcd-2fe2s-c_c0 + 2.0 sufse-c_c0'},
#  'new': {'reaction': 'cpd00001_c0 + cpd00002_c0 + cpd00982_c0 + 2.0 '
#                      'cpd10515_c0 + cpd32553 + 2.0 sufsesh-c_c0 --> '
#                      'cpd00008_c0 + cpd00009_c0 + cpd00015_c0 + 7.0 '
#                      'cpd00067_c0 + sufbcd-2fe2s-c_c0 + 2.0 sufse-c_c0'},
#  'justification': 'The non-ModelSEED ID sufbcd-c_c0 in this reaction '
#                   '(S2FE2SS_c0) must be replaced.'}
#
#
# {'original': {'reaction': '2fe1s-c_c0 + cpd00001_c0 + cpd00002_c0 + '
#                           'sufbcd-c_c0 + sufsesh-c_c0 --> cpd00008_c0 + '
#                           'cpd00009_c0 + 5.0 cpd00067_c0 + sufbcd-2fe2s-c_c0 + '
#                           'sufse-c_c0'},
#  'new': {'reaction': '2fe1s-c_c0 + cpd00001_c0 + cpd00002_c0 + cpd32553 + '
#                      'sufsesh-c_c0 --> cpd00008_c0 + cpd00009_c0 + 5.0 '
#                      'cpd00067_c0 + sufbcd-2fe2s-c_c0 + sufse-c_c0'},
#  'justification': 'The non-ModelSEED ID sufbcd-c_c0 in this reaction '
#                   '(S2FE2SR_c0) must be replaced.'}
#
#
# {'original': {'reaction': '4.0 cpd00067_c0 + sufbcd-4fe4s-c_c0 --> cpd24682_c0 '
#                           '+ sufbcd-c_c0'},
#  'new': {'reaction': '4.0 cpd00067_c0 + sufbcd-4fe4s-c_c0 --> cpd24682_c0 + '
#                      'cpd32553'},
#  'justification': 'The non-ModelSEED ID sufbcd-c_c0 in this reaction '
#                   '(S4FE4ST_c0) must be replaced.'}
#
#
# {'original': {'reaction': '4.0 cpd00067_c0 + sufbcd-2fe2s-c_c0 --> cpd24604_c0 '
#                           '+ sufbcd-c_c0'},
#  'new': {'reaction': '4.0 cpd00067_c0 + sufbcd-2fe2s-c_c0 --> cpd24604_c0 + '
#                      'cpd32553'},
#  'justification': 'The non-ModelSEED ID sufbcd-c_c0 in this reaction '
#                   '(S2FE2ST_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00005_c0 + cpd00067_c0 + dhmpt-c_c0 --> '
#                           'cpd00006_c0 + cpd26424_c0'},
#  'new': {'reaction': 'cpd00005_c0 + cpd00067_c0 + cpd32553 --> cpd00006_c0 + '
#                      'cpd26424_c0'},
#  'justification': 'The non-ModelSEED ID dhmpt-c_c0 in this reaction '
#                   '(DHMPTR_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd02961_c0 <=> dhmpt-c_c0'},
#  'new': {'reaction': 'cpd02961_c0 <=> cpd32553'},
#  'justification': 'The non-ModelSEED ID dhmpt-c_c0 in this reaction '
#                   '(DHNPTE_c0) must be replaced.'}
#
#
# {'original': {'reaction': '2.0 cpd00067_c0 + cpd15574_c0 + cpd21090_c0 --> '
#                           'cpd00001_c0 + cpd00018_c0 + cpd00058_c0 + wco-c_c0'},
#  'new': {'reaction': '2.0 cpd00067_c0 + cpd15574_c0 + cpd21090_c0 --> '
#                      'cpd00001_c0 + cpd00018_c0 + cpd00058_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID wco-c_c0 in this reaction (WCOS_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'cpd21090_c0 + wco-c_c0 --> bwco-c_c0 + cpd00018_c0 '
#                           '+ cpd00058_c0'},
#  'new': {'reaction': 'cpd21090_c0 + cpd32553 --> bwco-c_c0 + cpd00018_c0 + '
#                      'cpd00058_c0'},
#  'justification': 'The non-ModelSEED ID wco-c_c0 in this reaction (BWCOS_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'id': 'cpd03732', 'name': 'UDP-N-acetyl-D-mannosaminouronate_c0'},
#  'new': {'id': 'cpd02703', 'name': 'UDP-N-acetyl-D-mannosaminouronate'},
#  'justification': 'The cpd03732 and cpd02703 distinction is incompatible.'}
#
#
# {'original': {'reaction': 'cpd00003_c0 + 2.0 cpd00017_c0 + cpd00067_c0 + '
#                           'cpd24682_c0 + octapb-c_c0 --> cpd00004_c0 + 2.0 '
#                           'cpd00060_c0 + 2.0 cpd03091_c0 + 2.0 cpd10515_c0 + '
#                           'cpd24604_c0 + lipopb-c_c0'},
#  'new': {'reaction': 'cpd00003_c0 + 2.0 cpd00017_c0 + cpd00067_c0 + '
#                      'cpd24682_c0 + cpd32553 --> cpd00004_c0 + 2.0 cpd00060_c0 '
#                      '+ 2.0 cpd03091_c0 + 2.0 cpd10515_c0 + cpd24604_c0 + '
#                      'lipopb-c_c0'},
#  'justification': 'The non-ModelSEED ID octapb-c_c0 in this reaction '
#                   '(LIPOS_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00002_c0 + cpd00067_c0 + cpd03846_c0 --> '
#                           'cpd00012_c0 + cpd00018_c0 + octapb-c_c0'},
#  'new': {'reaction': 'cpd00002_c0 + cpd00067_c0 + cpd03846_c0 --> cpd00012_c0 '
#                      '+ cpd00018_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID octapb-c_c0 in this reaction '
#                   '(OCTNLL_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00067_c0 + cpd11470_c0 --> cpd11493_c0 + '
#                           'octapb-c_c0'},
#  'new': {'reaction': 'cpd00067_c0 + cpd11470_c0 --> cpd11493_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID octapb-c_c0 in this reaction '
#                   '(LIPOCT_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'bwco-c_c0 + cpd00038_c0 + cpd00067_c0 --> '
#                           'bwco1gdp-c_c0 + cpd00012_c0'},
#  'new': {'reaction': 'cpd00038_c0 + cpd00067_c0 + cpd32553 --> bwco1gdp-c_c0 + '
#                      'cpd00012_c0'},
#  'justification': 'The non-ModelSEED ID bwco-c_c0 in this reaction '
#                   '(BWCOGDS1_c0) must be replaced.'}
#
#
# {'original': {'id': 'dhps-c', 'name': '2,3-Dihydroxypropane-1-sulfonate'},
#  'new': {'id': 'cpd31356', 'name': '2,3-Dihydroxypropane-1-sulfonate'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'dhps-e_e0 <=> dhps-p_p0'},
#  'new': {'reaction': 'cpd31356 <=> dhps-p_p0'},
#  'justification': 'The non-ModelSEED ID dhps-e_e0 in this reaction '
#                   '(DHPStex_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'dhps-e_e0 <=> '},
#  'new': {'reaction': 'cpd31356 <=> '},
#  'justification': 'The non-ModelSEED ID dhps-e_e0 in this reaction '
#                   '(EX_dhps-e_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd31356 --> dhps-p_p0'},
#  'new': {'reaction': 'cpd31356 --> cpd31356'},
#  'justification': 'The non-ModelSEED ID dhps-p_p0 in this reaction (DHPStr_c0) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00084_c0 + sufse-c_c0 --> cpd00035_c0 + '
#                           'sufsesh-c_c0'},
#  'new': {'reaction': 'cpd00084_c0 + cpd32553 --> cpd00035_c0 + sufsesh-c_c0'},
#  'justification': 'The non-ModelSEED ID sufse-c_c0 in this reaction '
#                   '(SCYSDS_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00001_c0 + cpd00002_c0 + cpd00982_c0 + 2.0 '
#                           'cpd10515_c0 + sufbcd-2fe2s-c_c0 + 2.0 sufsesh-c_c0 '
#                           '--> cpd00008_c0 + cpd00009_c0 + cpd00015_c0 + 7.0 '
#                           'cpd00067_c0 + sufbcd-2fe2s2-c_c0 + 2.0 sufse-c_c0'},
#  'new': {'reaction': 'cpd00001_c0 + cpd00002_c0 + cpd00982_c0 + 2.0 '
#                      'cpd10515_c0 + sufbcd-2fe2s-c_c0 + 2.0 sufsesh-c_c0 --> '
#                      'cpd00008_c0 + cpd00009_c0 + cpd00015_c0 + 7.0 '
#                      'cpd00067_c0 + 2.0 cpd32553 + sufbcd-2fe2s2-c_c0'},
#  'justification': 'The non-ModelSEED ID sufse-c_c0 in this reaction '
#                   '(S2FE2SS2_c0) must be replaced.'}
#
#
# {'original': {'id': 'acampnt-c', 'name': '2-N-acetamidomethylphosphonate'},
#  'new': {'id': 'cpd35393', 'name': '2-N-acetamidomethylphosphonate'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'id': 'cpd00491', 'name': 'D-mannitol-1-phosphate_c0'},
#  'new': {'id': 'cpd27436', 'name': 'D-mannitol-1-phosphate'},
#  'justification': 'The cpd00491 and cpd27436 distinction is incompatible.'}
#
#
# {'original': {'id': 'cpd03191', 'name': 'D-Glucuronate 1-phosphate_p0'},
#  'new': {'id': 'cpd00880', 'name': 'D-Glucuronate 1-phosphate'},
#  'justification': 'The cpd03191 and cpd00880 distinction is incompatible.'}
#
#
# {'original': {'reaction': 'bwco1gdp-c_c0 + cpd00038_c0 + cpd00067_c0 --> '
#                           'bwcogdp-c_c0 + cpd00012_c0'},
#  'new': {'reaction': 'bwco1gdp-c_c0 + cpd00038_c0 + cpd00067_c0 --> '
#                      'cpd00012_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID bwcogdp-c_c0 in this reaction '
#                   '(BWCOGDS2_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd03191_e0 <=> '},
#  'new': {'reaction': 'cpd00880 <=> '},
#  'justification': 'The non-ModelSEED ID cpd03191_e0 in this reaction '
#                   '(EX_cpd03191_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd03191_e0 <=> cpd00880'},
#  'new': {'reaction': 'cpd00880 <=> cpd00880'},
#  'justification': 'The non-ModelSEED ID cpd03191_e0 in this reaction '
#                   '(GLCUR1Ptex_e0) must be replaced.'}
#
#
# {'original': {'id': 'tartr-D-p', 'name': 'D-tartrate'},
#  'new': {'id': 'cpd19018', 'name': 'D-tartrate'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'tartr-D-e_e0 <=> '},
#  'new': {'reaction': 'cpd19018 <=> '},
#  'justification': 'The non-ModelSEED ID tartr-D-e_e0 in this reaction '
#                   '(EX_tartr-D-e_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'tartr-D-e_e0 <=> cpd19018'},
#  'new': {'reaction': 'cpd19018 <=> cpd19018'},
#  'justification': 'The non-ModelSEED ID tartr-D-e_e0 in this reaction '
#                   '(TARTRDtex_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'tartr-D-c_c0 --> cpd00001_c0 + cpd00032_c0'},
#  'new': {'reaction': 'cpd19018 --> cpd00001_c0 + cpd00032_c0'},
#  'justification': 'The non-ModelSEED ID tartr-D-c_c0 in this reaction '
#                   '(DTARTD_c0) must be replaced.'}
#
#
# {'original': {'reaction': '3.0 cpd00067_p0 + cpd19018 --> 3.0 cpd00067_c0 + '
#                           'tartr-D-c_c0'},
#  'new': {'reaction': '3.0 cpd00067_p0 + cpd19018 --> 3.0 cpd00067_c0 + '
#                      'cpd19018'},
#  'justification': 'The non-ModelSEED ID tartr-D-c_c0 in this reaction '
#                   '(TARTt2__DASH__3pp_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00036_c0 + cpd19018 <=> cpd00036_p0 + '
#                           'tartr-D-c_c0'},
#  'new': {'reaction': 'cpd00036_c0 + cpd19018 <=> cpd00036_p0 + cpd19018'},
#  'justification': 'The non-ModelSEED ID tartr-D-c_c0 in this reaction '
#                   '(SUCTARTtpp_c0) must be replaced.'}
#
#
# {'original': {'id': 'dtgcl-c', 'name': '2-hydroxyethyldisulfide'},
#  'new': {'id': 'cpd26318', 'name': '2-hydroxyethyldisulfide'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': '2.0 cpd00038_c0 --> cdigmp-c_c0 + 2.0 cpd00012_c0'},
#  'new': {'reaction': '2.0 cpd00038_c0 --> 2.0 cpd00012_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID cdigmp-c_c0 in this reaction '
#                   '(DGUNC_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cdigmp-c_c0 + cpd00001_c0 --> cpd00067_c0 + '
#                           'cpd18057_c0'},
#  'new': {'reaction': 'cpd00001_c0 + cpd32553 --> cpd00067_c0 + cpd18057_c0'},
#  'justification': 'The non-ModelSEED ID cdigmp-c_c0 in this reaction '
#                   '(CDGUNPD_c0) must be replaced.'}
#
#
# {'original': {'id': '2dh3dgal-c', 'name': '2-Dehydro-3-deoxy-D-galactonate'},
#  'new': {'id': 'cpd00894', 'name': '2-Dehydro-3-deoxy-D-galactonate'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'id': 'cpd15411', 'name': 'aerobactin minus Fe3_p0'},
#  'new': {'id': 'cpd03294', 'name': 'aerobactin minus Fe3'},
#  'justification': 'The cpd15411 and cpd03294 distinction is incompatible.'}
#
#
# {'original': {'reaction': 'cpd15411_e0 <=> '},
#  'new': {'reaction': 'cpd03294 <=> '},
#  'justification': 'The non-ModelSEED ID cpd15411_e0 in this reaction '
#                   '(EX_cpd15411_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd10516_e0 + cpd15411_e0 --> cpd03294_e0'},
#  'new': {'reaction': 'cpd03294 + cpd10516_e0 --> cpd03294_e0'},
#  'justification': 'The non-ModelSEED ID cpd15411_e0 in this reaction '
#                   '(rxn08144_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00067_p0 + cpd03294 --> cpd00067_c0 + '
#                           'cpd15411_e0'},
#  'new': {'reaction': 'cpd00067_p0 + cpd03294 --> cpd00067_c0 + cpd03294'},
#  'justification': 'The non-ModelSEED ID cpd15411_e0 in this reaction '
#                   '(ARBTNtex_p0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd01270_c0 + 2.0 cpd03294_c0 --> cpd00050_c0 + 2.0 '
#                           'cpd00067_c0 + 2.0 cpd10515_c0 + 2.0 cpd15411_c0'},
#  'new': {'reaction': 'cpd01270_c0 + 2.0 cpd03294_c0 --> cpd00050_c0 + 2.0 '
#                      'cpd00067_c0 + 2.0 cpd03294 + 2.0 cpd10515_c0'},
#  'justification': 'The non-ModelSEED ID cpd15411_c0 in this reaction '
#                   '(rxn08146_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00067_p0 + cpd15411_c0 --> cpd00067_c0 + '
#                           'cpd03294'},
#  'new': {'reaction': 'cpd00067_p0 + cpd03294 --> cpd00067_c0 + cpd03294'},
#  'justification': 'The non-ModelSEED ID cpd15411_c0 in this reaction '
#                   '(ARBTNtpp_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00739_c0 + 2.0 cpd03294_c0 --> 2.0 cpd00067_c0 + '
#                           'cpd00220_c0 + 2.0 cpd10515_c0 + 2.0 cpd15411_c0'},
#  'new': {'reaction': 'cpd00739_c0 + 2.0 cpd03294_c0 --> 2.0 cpd00067_c0 + '
#                      'cpd00220_c0 + 2.0 cpd03294 + 2.0 cpd10515_c0'},
#  'justification': 'The non-ModelSEED ID cpd15411_c0 in this reaction '
#                   '(rxn08147_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00982_c0 + 2.0 cpd03294_c0 --> cpd00015_c0 + 2.0 '
#                           'cpd00067_c0 + 2.0 cpd10515_c0 + 2.0 cpd15411_c0'},
#  'new': {'reaction': 'cpd00982_c0 + 2.0 cpd03294_c0 --> cpd00015_c0 + 2.0 '
#                      'cpd00067_c0 + 2.0 cpd03294 + 2.0 cpd10515_c0'},
#  'justification': 'The non-ModelSEED ID cpd15411_c0 in this reaction '
#                   '(rxn08145_c0) must be replaced.'}
#
#
# {'original': {'reaction': '70.028756 cpd00001_c0 + 75.55223 cpd00002_c0 + '
#                           '0.001787 cpd00003_c0 + 4.5e-05 cpd00004_c0 + '
#                           '0.000335 cpd00005_c0 + 0.000112 cpd00006_c0 + '
#                           '0.000168 cpd00010_c0 + 0.012379 cpd00013_c0 + '
#                           '0.000223 cpd00015_c0 + 0.000223 cpd00016_c0 + '
#                           '0.000223 cpd00017_c0 + 0.000279 cpd00022_c0 + '
#                           '0.255712 cpd00023_c0 + 0.000223 cpd00028_c0 + '
#                           '0.000658 cpd00030_c0 + 0.595297 cpd00033_c0 + '
#                           '0.000324 cpd00034_c0 + 0.499149 cpd00035_c0 + '
#                           '0.209121 cpd00038_c0 + 0.333448 cpd00039_c0 + '
#                           '0.234232 cpd00041_c0 + 0.000223 cpd00042_c0 + '
#                           '0.004126 cpd00048_c0 + 0.28742 cpd00051_c0 + '
#                           '0.129799 cpd00052_c0 + 0.255712 cpd00053_c0 + '
#                           '0.209684 cpd00054_c0 + 0.000223 cpd00056_c0 + '
#                           '0.000674 cpd00058_c0 + 0.149336 cpd00060_c0 + '
#                           '0.140101 cpd00062_c0 + 0.004952 cpd00063_c0 + '
#                           '0.055234 cpd00065_c0 + 0.180021 cpd00066_c0 + '
#                           '0.133993 cpd00069_c0 + 3.1e-05 cpd00070_c0 + '
#                           '9.8e-05 cpd00078_c0 + 0.088988 cpd00084_c0 + '
#                           '0.000223 cpd00087_c0 + 0.004952 cpd00099_c0 + 2e-06 '
#                           'cpd00104_c0 + 0.437778 cpd00107_c0 + 0.024805 '
#                           'cpd00115_c0 + 0.03327 cpd00118_c0 + 0.092056 '
#                           'cpd00119_c0 + 0.000223 cpd00125_c0 + 0.214798 '
#                           'cpd00129_c0 + 0.234232 cpd00132_c0 + 2.4e-05 '
#                           'cpd00149_c0 + 0.154187 cpd00155_c0 + 0.411184 '
#                           'cpd00156_c0 + 0.246506 cpd00161_c0 + 0.000223 '
#                           'cpd00166_c0 + 0.000223 cpd00201_c0 + 0.18569 '
#                           'cpd00205_c0 + 0.000223 cpd00216_c0 + 0.000223 '
#                           'cpd00220_c0 + 0.025612 cpd00241_c0 + 0.000307 '
#                           'cpd00244_c0 + 0.008253 cpd00254_c0 + 0.006744 '
#                           'cpd00264_c0 + 0.282306 cpd00322_c0 + 0.000223 '
#                           'cpd00345_c0 + 0.025612 cpd00356_c0 + 0.024805 '
#                           'cpd00357_c0 + 0.000223 cpd00557_c0 + 0.000223 '
#                           'cpd03453_c0 + 0.006388 cpd10515_c0 + 0.007428 '
#                           'cpd10516_c0 + 0.000223 cpd11313_c0 + 7e-06 '
#                           'cpd11574_c0 + 0.000223 cpd15353_c0 + 0.002944 '
#                           'cpd15428_p0 + 0.00229 cpd15429_p0 + 0.00118 '
#                           'cpd15431_p0 + 0.008151 cpd15432_e0 + 0.000223 '
#                           'cpd15499_c0 + 0.001345 cpd15501_p0 + 0.000605 '
#                           'cpd15503_p0 + 0.005381 cpd15505_p0 + 0.005448 '
#                           'cpd15506_p0 + 0.000673 cpd15508_p0 + 0.044164 '
#                           'cpd15531_p0 + 0.03435 cpd15532_p0 + 0.017704 '
#                           'cpd15534_p0 + 0.010599 cpd15538_p0 + 0.008244 '
#                           'cpd15539_p0 + 0.004249 cpd15541_p0 + 0.000223 '
#                           'cpd15561_c0 + 7e-06 cpd21288_c0 + 2.5e-05 '
#                           'cpd24604_c0 + 0.000248 cpd24682_c0 + 5.5e-05 '
#                           'cpd25775_c0 + 3e-06 lipopb-c_c0 + 7e-06 '
#                           'mocogdp-c_c0 --> 75.37723 cpd00008_c0 + 75.37323 '
#                           'cpd00009_c0 + 0.749831 cpd00012_c0 + 75.37723 '
#                           'cpd00067_c0'},
#  'new': {'reaction': '70.028756 cpd00001_c0 + 75.55223 cpd00002_c0 + 0.001787 '
#                      'cpd00003_c0 + 4.5e-05 cpd00004_c0 + 0.000335 cpd00005_c0 '
#                      '+ 0.000112 cpd00006_c0 + 0.000168 cpd00010_c0 + 0.012379 '
#                      'cpd00013_c0 + 0.000223 cpd00015_c0 + 0.000223 '
#                      'cpd00016_c0 + 0.000223 cpd00017_c0 + 0.000279 '
#                      'cpd00022_c0 + 0.255712 cpd00023_c0 + 0.000223 '
#                      'cpd00028_c0 + 0.000658 cpd00030_c0 + 0.595297 '
#                      'cpd00033_c0 + 0.000324 cpd00034_c0 + 0.499149 '
#                      'cpd00035_c0 + 0.209121 cpd00038_c0 + 0.333448 '
#                      'cpd00039_c0 + 0.234232 cpd00041_c0 + 0.000223 '
#                      'cpd00042_c0 + 0.004126 cpd00048_c0 + 0.28742 cpd00051_c0 '
#                      '+ 0.129799 cpd00052_c0 + 0.255712 cpd00053_c0 + 0.209684 '
#                      'cpd00054_c0 + 0.000223 cpd00056_c0 + 0.000674 '
#                      'cpd00058_c0 + 0.149336 cpd00060_c0 + 0.140101 '
#                      'cpd00062_c0 + 0.004952 cpd00063_c0 + 0.055234 '
#                      'cpd00065_c0 + 0.180021 cpd00066_c0 + 0.133993 '
#                      'cpd00069_c0 + 3.1e-05 cpd00070_c0 + 9.8e-05 cpd00078_c0 '
#                      '+ 0.088988 cpd00084_c0 + 0.000223 cpd00087_c0 + 0.004952 '
#                      'cpd00099_c0 + 2e-06 cpd00104_c0 + 0.437778 cpd00107_c0 + '
#                      '0.024805 cpd00115_c0 + 0.03327 cpd00118_c0 + 0.092056 '
#                      'cpd00119_c0 + 0.000223 cpd00125_c0 + 0.214798 '
#                      'cpd00129_c0 + 0.234232 cpd00132_c0 + 2.4e-05 cpd00149_c0 '
#                      '+ 0.154187 cpd00155_c0 + 0.411184 cpd00156_c0 + 0.246506 '
#                      'cpd00161_c0 + 0.000223 cpd00166_c0 + 0.000223 '
#                      'cpd00201_c0 + 0.18569 cpd00205_c0 + 0.000223 cpd00216_c0 '
#                      '+ 0.000223 cpd00220_c0 + 0.025612 cpd00241_c0 + 0.000307 '
#                      'cpd00244_c0 + 0.008253 cpd00254_c0 + 0.006744 '
#                      'cpd00264_c0 + 0.282306 cpd00322_c0 + 0.000223 '
#                      'cpd00345_c0 + 0.025612 cpd00356_c0 + 0.024805 '
#                      'cpd00357_c0 + 0.000223 cpd00557_c0 + 0.000223 '
#                      'cpd03453_c0 + 0.006388 cpd10515_c0 + 0.007428 '
#                      'cpd10516_c0 + 0.000223 cpd11313_c0 + 7e-06 cpd11574_c0 + '
#                      '0.000223 cpd15353_c0 + 0.002944 cpd15428_p0 + 0.00229 '
#                      'cpd15429_p0 + 0.00118 cpd15431_p0 + 0.008151 cpd15432_e0 '
#                      '+ 0.000223 cpd15499_c0 + 0.001345 cpd15501_p0 + 0.000605 '
#                      'cpd15503_p0 + 0.005381 cpd15505_p0 + 0.005448 '
#                      'cpd15506_p0 + 0.000673 cpd15508_p0 + 0.044164 '
#                      'cpd15531_p0 + 0.03435 cpd15532_p0 + 0.017704 cpd15534_p0 '
#                      '+ 0.010599 cpd15538_p0 + 0.008244 cpd15539_p0 + 0.004249 '
#                      'cpd15541_p0 + 0.000223 cpd15561_c0 + 7e-06 cpd21288_c0 + '
#                      '2.5e-05 cpd24604_c0 + 0.000248 cpd24682_c0 + 5.5e-05 '
#                      'cpd25775_c0 + 3e-06 cpd32553 + 7e-06 mocogdp-c_c0 --> '
#                      '75.37723 cpd00008_c0 + 75.37323 cpd00009_c0 + 0.749831 '
#                      'cpd00012_c0 + 75.37723 cpd00067_c0'},
#  'justification': 'The non-ModelSEED ID lipopb-c_c0 in this reaction (bio2) '
#                   'must be replaced.'}
#
#
# {'original': {'reaction': 'cpd14955_c0 --> cpd00018_c0 + lipopb-c_c0'},
#  'new': {'reaction': 'cpd14955_c0 --> cpd00018_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID lipopb-c_c0 in this reaction '
#                   '(LIPAMPL_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'ampnt-c_c0 + cpd00022_c0 --> cpd00010_c0 + '
#                           'cpd35393'},
#  'new': {'reaction': 'cpd00022_c0 + cpd32553 --> cpd00010_c0 + cpd35393'},
#  'justification': 'The non-ModelSEED ID ampnt-c_c0 in this reaction '
#                   '(AMPNTAT_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'apoACP-c_c0 + cpd00010_c0 --> cpd00045_c0 + '
#                           'cpd00067_c0 + cpd11493_c0'},
#  'new': {'reaction': 'cpd00010_c0 + cpd32553 --> cpd00045_c0 + cpd00067_c0 + '
#                      'cpd11493_c0'},
#  'justification': 'The non-ModelSEED ID apoACP-c_c0 in this reaction '
#                   '(ACPS1_c0) must be replaced.'}
#
#
# {'original': {'id': 'cpd15377',
#               'name': '3-Oxooctadecanoyl-[acyl-carrier protein]_c0'},
#  'new': {'id': 'cpd14938', 'name': '3-Oxooctadecanoyl-[acyl-carrier protein]'},
#  'justification': 'The cpd15377 and cpd14938 distinction is incompatible.'}
#
#
# {'original': {'reaction': '4.0 cpd00067_c0 + iscu-4fe4s-c_c0 --> cpd24682_c0 + '
#                           'iscu-c_c0'},
#  'new': {'reaction': '4.0 cpd00067_c0 + iscu-4fe4s-c_c0 --> cpd24682_c0 + '
#                      'cpd32553'},
#  'justification': 'The non-ModelSEED ID iscu-c_c0 in this reaction '
#                   '(I4FE4ST_c0) must be replaced.'}
#
#
# {'original': {'reaction': '4.0 cpd00067_c0 + iscu-2fe2s-c_c0 --> cpd24604_c0 + '
#                           'iscu-c_c0'},
#  'new': {'reaction': '4.0 cpd00067_c0 + iscu-2fe2s-c_c0 --> cpd24604_c0 + '
#                      'cpd32553'},
#  'justification': 'The non-ModelSEED ID iscu-c_c0 in this reaction '
#                   '(I2FE2ST_c0) must be replaced.'}
#
#
# {'original': {'id': 'sfp-c', 'name': '6-deoxy-6-sulphofructose 1-phosphate'},
#  'new': {'id': 'cpd32891', 'name': '6-deoxy-6-sulphofructose 1-phosphate'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'cpd00005_c0 + gslnt-c_c0 --> cpd00006_c0 + '
#                           'cpd00042_c0 + cpd01078_c0'},
#  'new': {'reaction': 'cpd00005_c0 + cpd32553 --> cpd00006_c0 + cpd00042_c0 + '
#                      'cpd01078_c0'},
#  'justification': 'The non-ModelSEED ID gslnt-c_c0 in this reaction '
#                   '(SELGTHR3_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00005_c0 + cpd00067_c0 + cpd20131_c0 --> '
#                           'cpd00006_c0 + cpd00042_c0 + gslnt-c_c0'},
#  'new': {'reaction': 'cpd00005_c0 + cpd00067_c0 + cpd20131_c0 --> cpd00006_c0 '
#                      '+ cpd00042_c0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID gslnt-c_c0 in this reaction '
#                   '(SELGTHR2_c0) must be replaced.'}
#
#
# {'original': {'id': 'cpd00804', 'name': 'Sorbitol 6-phosphate_c0'},
#  'new': {'id': 'cpd00491', 'name': 'Sorbitol 6-phosphate'},
#  'justification': 'The cpd00804 and cpd00491 distinction is incompatible.'}
#
#
# {'original': {'id': '2hptcoa-c',
#               'name': '2-hydroxycyclohepta-1,4,6-triene-1-carboxyl-CoA'},
#  'new': {'id': 'cpd34745',
#          'name': '2-hydroxycyclohepta-1,4,6-triene-1-carboxyl-CoA'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'id': 'xylu-D-c', 'name': 'D-Xylulose'},
#  'new': {'id': 'cpd00259', 'name': 'D-Xylulose'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'id': 'cpd15268', 'name': 'Octadecanoyl-ACP_c0'},
#  'new': {'id': 'cpd12458', 'name': 'Octadecanoyl-ACP'},
#  'justification': 'The cpd15268 and cpd12458 distinction is incompatible.'}
#
#
# {'original': {'id': 'metsox-R-L-p', 'name': 'L-methionine-R-sulfoxide'},
#  'new': {'id': 'cpd14720', 'name': 'L-methionine-R-sulfoxide'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'cpd00025_c0 + cpd00060_c0 --> cpd00001_c0 + '
#                           'metsox-R-L-c_c0'},
#  'new': {'reaction': 'cpd00025_c0 + cpd00060_c0 --> cpd00001_c0 + cpd14720'},
#  'justification': 'The non-ModelSEED ID metsox-R-L-c_c0 in this reaction '
#                   '(METOX2s_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd00001_c0 + cpd00002_c0 + cpd14720 --> '
#                           'cpd00008_c0 + cpd00009_c0 + cpd00067_c0 + '
#                           'metsox-R-L-c_c0'},
#  'new': {'reaction': 'cpd00001_c0 + cpd00002_c0 + cpd14720 --> cpd00008_c0 + '
#                      'cpd00009_c0 + cpd00067_c0 + cpd14720'},
#  'justification': 'The non-ModelSEED ID metsox-R-L-c_c0 in this reaction '
#                   '(METSOX2abcpp_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'cpd11421_c0 + metsox-R-L-c_c0 --> cpd00001_c0 + '
#                           'cpd00060_c0 + cpd11420_c0'},
#  'new': {'reaction': 'cpd11421_c0 + cpd14720 --> cpd00001_c0 + cpd00060_c0 + '
#                      'cpd11420_c0'},
#  'justification': 'The non-ModelSEED ID metsox-R-L-c_c0 in this reaction '
#                   '(METSOXR2_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'metsox-R-L-e_e0 <=> cpd14720'},
#  'new': {'reaction': 'cpd14720 <=> cpd14720'},
#  'justification': 'The non-ModelSEED ID metsox-R-L-e_e0 in this reaction '
#                   '(METSOX2tex_e0) must be replaced.'}
#
#
# {'original': {'reaction': 'metsox-R-L-e_e0 <=> '},
#  'new': {'reaction': 'cpd14720 <=> '},
#  'justification': 'The non-ModelSEED ID metsox-R-L-e_e0 in this reaction '
#                   '(EX_metsox-R-L-e_e0) must be replaced.'}
#
#
# {'original': {'id': 'cpd15478', 'name': 'gamma-glutamyl-putrescine_c0'},
#  'new': {'id': 'cpd11340', 'name': 'gamma-glutamyl-putrescine'},
#  'justification': 'The cpd15478 and cpd11340 distinction is incompatible.'}
#
#
# {'original': {'id': '4abzglu-e', 'name': '4-aminobenzoyl-glutamate'},
#  'new': {'id': 'cpd26527', 'name': '4-aminobenzoyl-glutamate'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': '4abzglu-p_p0 + cpd00067_p0 <=> 4abzglu-c_c0 + '
#                           'cpd00067_c0'},
#  'new': {'reaction': '4abzglu-p_p0 + cpd00067_p0 <=> cpd00067_c0 + cpd26527'},
#  'justification': 'The non-ModelSEED ID 4abzglu-c_c0 in this reaction '
#                   '(4ABZGLUtr_c0) must be replaced.'}
#
#
# {'original': {'reaction': '4abzglu-c_c0 + cpd00001_c0 <=> cpd00023_c0 + '
#                           'cpd00443_c0'},
#  'new': {'reaction': 'cpd00001_c0 + cpd26527 <=> cpd00023_c0 + cpd00443_c0'},
#  'justification': 'The non-ModelSEED ID 4abzglu-c_c0 in this reaction '
#                   '(4ABZGLUH_c0) must be replaced.'}
#
#
# {'original': {'id': 'cpd15494', 'name': 'Maltoheptaose_c0'},
#  'new': {'id': 'cpd03718', 'name': 'Maltoheptaose'},
#  'justification': 'The cpd15494 and cpd03718 distinction is incompatible.'}
#
#
# {'original': {'reaction': 'cpd26527 <=> 4abzglu-p_p0'},
#  'new': {'reaction': 'cpd26527 <=> cpd26527'},
#  'justification': 'The non-ModelSEED ID 4abzglu-p_p0 in this reaction '
#                   '(4ABZGLUtex_e0) must be replaced.'}
#
#
# {'original': {'id': 'sf-c', 'name': '6-deoxy-6-sulphofructose'},
#  'new': {'id': 'cpd35501', 'name': '6-deoxy-6-sulphofructose'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'id': 'bmocogdp-c',
#               'name': 'Bis-molybdopterin guanine dinucleotide'},
#  'new': {'id': 'cpd37287', 'name': 'Molybdopterin guanine dinucleotide'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'cpd00038_c0 + cpd00067_c0 + cpd19503_c0 --> '
#                           'cpd00012_c0 + mocogdp-c_c0'},
#  'new': {'reaction': 'cpd00038_c0 + cpd00067_c0 + cpd19503_c0 --> cpd00012_c0 '
#                      '+ cpd37287'},
#  'justification': 'The non-ModelSEED ID mocogdp-c_c0 in this reaction '
#                   '(MOGDS_c0) must be replaced.'}
#
#
# {'original': {'id': 'xylu-L-c', 'name': 'L-Xylulose'},
#  'new': {'id': 'cpd00261', 'name': 'L-Xylulose'},
#  'justification': 'The {original_id} ID is not a ModelSEED Database ID.'}
#
#
# {'original': {'reaction': 'cpd15432_p0 + cpd25775_p0 --> colipap-p_p0 + '
#                           'cpd00286_p0'},
#  'new': {'reaction': 'cpd15432_p0 + cpd25775_p0 --> cpd00286_p0 + cpd32553'},
#  'justification': 'The non-ModelSEED ID colipap-p_p0 in this reaction '
#                   '(COLIPAKpp_p0) must be replaced.'}
#
#
# {'original': {'reaction': 'colipap-p_p0 + cpd00001_c0 + cpd00002_c0 --> '
#                           'colipap-e_e0 + cpd00008_c0 + cpd00009_c0 + '
#                           'cpd00067_c0'},
#  'new': {'reaction': 'cpd00001_c0 + cpd00002_c0 + cpd32553 --> colipap-e_e0 + '
#                      'cpd00008_c0 + cpd00009_c0 + cpd00067_c0'},
#  'justification': 'The non-ModelSEED ID colipap-p_p0 in this reaction '
#                   '(COLIPAPabctex_c0) must be replaced.'}
#
#
# {'original': {'reaction': 'colipap-e_e0 <=> '},
#  'new': {'reaction': 'cpd32553 <=> '},
#  'justification': 'The non-ModelSEED ID colipap-e_e0 in this reaction '
#                   '(EX_colipap-e_e0) must be replaced.'}
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite sufbcd-4fe4s-c_c0 | SufBCD with bound [4Fe-4S] cluster is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite sufbcd-4fe4s-c_c0 | SufBCD with bound [4Fe-4S] cluster was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite prcp-c_c0 | 5-phospho-?-D-ribose 1,2-cyclic phosphate is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite prcp-c_c0 | 5-phospho-?-D-ribose 1,2-cyclic phosphate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite 3fe4s-c_c0 | [3Fe-4S] damaged iron-sulfur cluster is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite 3fe4s-c_c0 | [3Fe-4S] damaged iron-sulfur cluster was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite sufbcd-2fe2s-c_c0 | SufBCD with bound [2Fe-2S] cluster is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite sufbcd-2fe2s-c_c0 | SufBCD with bound [2Fe-2S] cluster was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite rpntp-c_c0 | ?-D-ribose-1-methylphosphonate-5-triphosphate is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite rpntp-c_c0 | ?-D-ribose-1-methylphosphonate-5-triphosphate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite metsox-S-L-c_c0 | L-Methionine Sulfoxide was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite metsox-S-L-p_p0 | L-Methionine Sulfoxide was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite dhptdd-c_c0 | 3-hydroxy-5-phosphonooxypentane-2,4-dione is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# ...
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r484_c0 | L-O-phosphoserine was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r1535_e0 | H+ involved in electron transport and ATP generation was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r1534_c0 | H+ involved in electron transport and ATP generation was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r1539_b0 | Exported alginate, DA=0.19 was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r1537_b0 | choline sulfate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r273_b0 | Hg0 was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r1540_b0 | Exported alginate, DA=0.32 was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r274_b0 | protoheme IX was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r271_b0 | 3-phenylpropionate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r272_b0 | D-glucarate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r270_b0 | tetradecanoate (n-C14:0) was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r277_e0 | 2-dehydro-D-gluconate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r276_b0 | xanthine was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r275_b0 | heme  was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite r856_c0 | coumarinic acid-beta-D-glucoside is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r856_c0 | coumarinic acid-beta-D-glucoside was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite r498_c0 | apo-[acp] is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r498_c0 | apo-[acp] was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r293_e0 | Fe2+ was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r431_c0 | undecaprenyl diphosphate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:53: UserWarning: ModelSEEDError: The metabolite r463_c0 | glycyl-tRNAgly is not recognized by the ModelSEED Database
#   warn(f'ModelSEEDError: The metabolite {met.id} | {met.name} is not recognized by the ModelSEED Database')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r463_c0 | glycyl-tRNAgly was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r462_c0 | tRNAgly was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r468_c0 | an oxidized cytochrome c was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r467_c0 | a reduced cytochrome c was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r458_c0 | 2-maleylacetate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r209_b0 | citrate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r208_b0 | choline was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r207_b0 | HCO3- was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r205_b0 | L-aspartate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r204_b0 | ammonia was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r203_b0 | allantoin was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r404_c0 | Tetradecanoyl-CoA (n-C14:0CoA) was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r229_b0 | sn-glycerol-3-phosphate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r228_b0 | glycerol was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r222_b0 | mannitol was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r221_b0 | D-malate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r220_b0 | D-lactate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r227_b0 | fumarate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r226_b0 | Dodecanoate (n-C12:0) was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r225_b0 | D-methionine was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r218_b0 | gluconate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r217_b0 | D-galactonate was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r219_b0 | glyceraldehyde was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r210_b0 | CO2 was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r211_b0 | cytosine was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r214_b0 | D-cysteine was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r213_b0 | D-alanine was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r216_b0 | Decanoate (n-C10:0) was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r215_b0 | D-serine was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:58: UserWarning: CodeError: The metabolite r410_c0 | butACP was not corrected to a ModelSEED metabolite.
#   warn(f'CodeError: The metabolite {met.id} | {met.name} was not corrected to a ModelSEED metabolite.')
# 1 511
# The metabolite is in model 0
# The metabolite is in model 1

# %% [markdown]
# # Brainstorming

# %%
pfba, self_pfba = None, False
if pfba == None or self_pfba == None:
    print('yes')

# %%
if 'cpd00035' in model1.metabolites:
    print('not replaced')

# %%
from cobra.core.dictlist import DictList

test = DictList()
test.append({'a':4, 'b':5})
print(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 from cobra.core.dictlist import DictList
#       3 test = DictList()
# ----> 4 test.append({'a':4, 'b':5})
#       5 print(test)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\dictlist.py:180, in DictList.append(self, entity)
#     178 def append(self, entity: Object) -> None:
#     179     """Append object to end."""
# --> 180     the_id = entity.id
#     181     self._check(the_id)
#     182     self._dict[the_id] = len(self)
#
# AttributeError: 'dict' object has no attribute 'id'

# %%
from collections import OrderedDict

x = OrderedDict({'x':2, 'c':4})
x.pop('c')
print(x)
print(list(x.keys()).index('x'))
print(dir(x))

# %%
print(model1.annotation)
# print(dir(model1))

for met in model.metabolites:
    print(dir(met))
    print(met.summary())
    if met == model.metabolites[4]:
        break
# Out:
# {}
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_annotation', '_bound', '_id', '_model', '_reaction', '_repr_html_', '_set_id_with_model', '_to_json', 'aliases', 'annotation', 'charge', 'compartment', 'compound_id', 'compound_ref', 'constraint', 'copy', 'dblinks', 'elements', 'formula', 'formula_weight', 'from_json', 'id', 'model', 'name', 'notes', 'numerical_attributes', 'reactions', 'remove_from_model', 'shadow_price', 'string_attributes', 'summary', 'y']
# cpd27374_c0
# ===========
# Formula: *
#
# Producing Reactions
# -------------------
# Empty DataFrame
# Columns: [Percent, Flux, Reaction, Definition]
# Index: []
#
# Consuming Reactions
# -------------------
# Empty DataFrame
# Columns: [Percent, Flux, Reaction, Definition]
# Index: []
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_annotation', '_bound', '_id', '_model', '_reaction', '_repr_html_', '_set_id_with_model', '_to_json', 'aliases', 'annotation', 'charge', 'compartment', 'compound_id', 'compound_ref', 'constraint', 'copy', 'dblinks', 'elements', 'formula', 'formula_weight', 'from_json', 'id', 'model', 'name', 'notes', 'numerical_attributes', 'reactions', 'remove_from_model', 'shadow_price', 'string_attributes', 'summary', 'y']
# cpd00009_e0
# ===========
# Formula: HO4P
#
# Producing Reactions
# -------------------
# Percent  Flux                 Reaction                                              Definition
# 100.00% 735.4 ENZRXN3EM__DASH__1536_c0 cpd00009_c0 + cpd00080_e0 --> cpd00009_e0 + cpd00080_c0
#
# Consuming Reactions
# -------------------
# Percent   Flux                                            Reaction                                                              Definition
#  38.57% -283.6 ENZRXN3EM__DASH__469__DASH__ENZRXN3EM__DASH__536_c0 cpd00001_c0 + cpd00002_c0 + cpd00009_e0 --> cpd00008_c0 + 2 cpd00009_c0
#  61.43% -451.7                                      EX_cpd00009_e0                                                        cpd00009_e0 <=>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_annotation', '_bound', '_id', '_model', '_reaction', '_repr_html_', '_set_id_with_model', '_to_json', 'aliases', 'annotation', 'charge', 'compartment', 'compound_id', 'compound_ref', 'constraint', 'copy', 'dblinks', 'elements', 'formula', 'formula_weight', 'from_json', 'id', 'model', 'name', 'notes', 'numerical_attributes', 'reactions', 'remove_from_model', 'shadow_price', 'string_attributes', 'summary', 'y']
# cpd00009_c0
# ===========
# Formula: HO4P
#
# Producing Reactions
# -------------------
# Percent    Flux                                                                        Reaction                                                                      Definition
#   0.05%   1.999 ENZRXN3EM__DASH__1446__DASH__ENZRXN3EM__DASH__1523__DASH__ENZRXN3EM__DASH__4... cpd00001_c0 + cpd00002_c0 + cpd00119_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   0.16%   6.242                                                        ENZRXN3EM__DASH__1518_c0 cpd00001_c0 + cpd00002_c0 + cpd00051_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   3.01%   115.5                                                        ENZRXN3EM__DASH__1568_c0 cpd00002_c0 + cpd00242_c0 + cpd02140_c0 --> cpd00008_c0 + cpd00009_c0 + r128...
#   0.12%   4.665 ENZRXN3EM__DASH__179__DASH__ENZRXN3EM__DASH__329__DASH__ENZRXN3EM__DASH__469... cpd00001_c0 + cpd00002_c0 + cpd00129_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#  14.79%   567.3                             ENZRXN3EM__DASH__469__DASH__ENZRXN3EM__DASH__536_c0         cpd00001_c0 + cpd00002_c0 + cpd00009_e0 --> cpd00008_c0 + 2 cpd00009_c0
#   0.00% 0.01111                                                        ENZRXN3EM__DASH__4700_c0   cpd00001_c0 + cpd00002_c0 + r1400_e0 --> cpd00008_c0 + cpd00009_c0 + r1399_c0
#   0.25%   9.507 ENZRXN3EM__DASH__4709__DASH__ENZRXN3EM__DASH__103__DASH__ENZRXN3EM__DASH__77... cpd00001_c0 + cpd00002_c0 + cpd00107_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   0.08%   3.243                                                        ENZRXN3EM__DASH__4716_c0 cpd00001_c0 + cpd00002_c0 + cpd00060_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   6.32%   242.3                                    ENZRXN3EM__DASH__59__DASH__MTRXN__DASH__1_c0 cpd00001_c0 + cpd00002_c0 + cpd00053_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   0.85%   32.65       ENZRXN3EM__DASH__6__DASH__ENZRXN3EM__DASH__4724__DASH__MTRXN__DASH__64_c0 cpd00001_c0 + cpd00002_c0 + cpd00023_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   3.01%   115.5                                                         ENZRXN3EM__DASH__785_c0 cpd00002_c0 + cpd00041_c0 + r631_c0 --> cpd00008_c0 + cpd00009_c0 + cpd02921_c0
#   0.02%   0.622                                                         ENZRXN3EM__DASH__876_c0    cpd00002_c0 + cpd00525_c0 + r1243_c0 --> cpd00008_c0 + cpd00009_c0 + r428_c0
#   1.16%   44.43                                                         ENZRXN3EM__DASH__924_c0             cpd11225_c0 + r654_c0 --> 2 cpd00001_c0 + cpd00009_c0 + cpd02656_c0
#   3.01%   115.5                                                         ENZRXN3EM__DASH__927_c0 cpd00002_c0 + cpd00033_c0 + r675_c0 --> cpd00008_c0 + cpd00009_c0 + cpd02394_c0
#   0.02%  0.7114     MTRXN__DASH__33__DASH__ENZRXN3EM__DASH__176__DASH__ENZRXN3EM__DASH__4696_c0 cpd00001_c0 + cpd00002_c0 + cpd00118_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   0.00% 0.01111                                       MTRXN__DASH__50__DASH__MTRXN__DASH__51_c0    cpd00001_c0 + cpd00002_c0 + r293_e0 --> cpd00008_c0 + cpd00009_c0 + r1004_c0
#   0.19%   7.241                                                              MTRXN__DASH__69_c0 cpd00001_c0 + cpd00002_c0 + cpd00039_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   1.79%   68.57                                                              MTRXN__DASH__80_c0 cpd00001_c0 + cpd00002_c0 + cpd08023_e0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   0.58%   22.21                                                             MVRXN__DASH__228_c0                             cpd00001_c0 + cpd02720_c0 --> cpd00009_c0 + r654_c0
#   0.02%   0.622                                                              MVRXN__DASH__67_c0               cpd00001_c0 + r431_c0 --> cpd00009_c0 + cpd00067_c0 + cpd00286_c0
#   0.02%   0.622                                                              MVRXN__DASH__68_c0 cpd00002_c0 + cpd00731_c0 + r428_c0 --> cpd00008_c0 + cpd00009_c0 + cpd00067...
#  21.96%     842                                                                     rxn00001_c0                                     cpd00001_c0 + cpd00012_c0 --> 2 cpd00009_c0
#   0.09%   3.363                                                                     rxn00412_c0 cpd00001_c0 + cpd00002_c0 + cpd00053_c0 + cpd00062_c0 --> cpd00008_c0 + cpd0...
#   0.02%   0.622                                                                     rxn00461_c0                         cpd00037_c0 + cpd00061_c0 --> cpd00009_c0 + cpd02820_c0
#  23.39%   896.7                                                                     rxn00533_c0 cpd00002_c0 + cpd00022_c0 + cpd00067_c0 + cpd00242_c0 --> cpd00008_c0 + cpd0...
#   3.01%   115.5                                                                     rxn00838_c0 cpd00038_c0 + cpd00041_c0 + cpd00114_c0 --> cpd00009_c0 + cpd00031_c0 + cpd0...
#   0.02%   0.622                                                                     rxn00851_c0         cpd00002_c0 + 2 cpd00117_c0 --> cpd00008_c0 + cpd00009_c0 + cpd00731_c0
#   0.03%   1.111                                                                     rxn01603_c0 cpd00002_c0 + cpd00023_c0 + cpd00683_c0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   1.76%   67.67                                                                     rxn01643_c0 cpd00006_c0 + cpd00009_c0 + cpd00346_c0 <=> cpd00005_c0 + cpd00067_c0 + cpd0...
#   0.02%   0.622                                                                     rxn02008_c0 cpd00002_c0 + cpd00186_c0 + cpd00890_c0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   0.02%   0.622                                                                     rxn02286_c0 cpd00002_c0 + cpd00035_c0 + cpd00773_c0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   3.01%   115.5                                                                     rxn02937_c0           cpd00002_c0 + cpd02826_c0 --> cpd00008_c0 + cpd00009_c0 + cpd02140_c0
#   3.01%   115.5                                                                     rxn03084_c0 cpd00001_c0 + cpd00002_c0 + cpd00053_c0 + cpd02678_c0 --> cpd00008_c0 + cpd0...
#   0.58%   22.35                                                                     rxn04783_c0 cpd00002_c0 + cpd00047_c0 + cpd02394_c0 --> cpd00008_c0 + cpd00009_c0 + cpd0...
#   0.00% 0.03332                                                                     rxn09101_c0                         cpd00001_c0 + cpd15542_c0 --> cpd00009_c0 + cpd15535_c0
#   0.00% 0.03332                                                                     rxn09104_c0                         cpd00001_c0 + cpd15545_c0 --> cpd00009_c0 + cpd15538_c0
#   0.00% 0.03332                                                                     rxn09105_c0                         cpd00001_c0 + cpd15546_c0 --> cpd00009_c0 + cpd15539_c0
#   0.00% 0.03332                                                                     rxn09106_c0                         cpd00001_c0 + cpd15547_c0 --> cpd00009_c0 + cpd15540_c0
#   0.00% 0.03332                                                                     rxn09107_c0                         cpd00001_c0 + cpd15548_c0 --> cpd00009_c0 + cpd15541_c0
#   3.43%   131.5                                                                     rxn15494_c0                         cpd00001_c0 + cpd19036_c0 --> cpd00009_c0 + cpd19035_c0
#   0.03%   1.111                                                                     rxn30654_c0                         cpd00001_c0 + cpd03521_c0 --> cpd00009_c0 + cpd02961_c0
#   4.17%     160                                                                     rxn32421_c0           cpd00001_c0 + cpd00011_c0 + cpd00061_c0 --> cpd00009_c0 + cpd00032_c0
#
# Consuming Reactions
# -------------------
# Percent   Flux                 Reaction                                                                      Definition
#  19.18% -735.4 ENZRXN3EM__DASH__1536_c0                         cpd00009_c0 + cpd00080_e0 --> cpd00009_e0 + cpd00080_c0
#  26.08%  -1000  ENZRXN3EM__DASH__178_c0 cpd00008_c0 + cpd00009_c0 + 4 r1535_e0 <=> cpd00001_c0 + cpd00002_c0 + 4 r15...
#  15.14% -580.5              rxn00173_c0                         cpd00009_c0 + cpd00022_c0 <=> cpd00010_c0 + cpd00196_c0
#  10.48% -401.9              rxn00285_c0 cpd00002_c0 + cpd00010_c0 + cpd00036_c0 <=> cpd00008_c0 + cpd00009_c0 + cpd0...
#   3.04% -116.6              rxn01019_c0                         cpd00064_c0 + cpd00146_c0 <=> cpd00009_c0 + cpd00274_c0
#  26.08%  -1000              rxn33210_c0 cpd00003_c0 + cpd00009_c0 + cpd00102_c0 <=> cpd00004_c0 + cpd00067_c0 + cpd2...
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_annotation', '_bound', '_id', '_model', '_reaction', '_repr_html_', '_set_id_with_model', '_to_json', 'aliases', 'annotation', 'charge', 'compartment', 'compound_id', 'compound_ref', 'constraint', 'copy', 'dblinks', 'elements', 'formula', 'formula_weight', 'from_json', 'id', 'model', 'name', 'notes', 'numerical_attributes', 'reactions', 'remove_from_model', 'shadow_price', 'string_attributes', 'summary', 'y']
# cpd05186_c0
# ===========
# Formula: C4H10N2O3
#
# Producing Reactions
# -------------------
# Empty DataFrame
# Columns: [Percent, Flux, Reaction, Definition]
# Index: []
#
# Consuming Reactions
# -------------------
# Empty DataFrame
# Columns: [Percent, Flux, Reaction, Definition]
# Index: []
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_annotation', '_bound', '_id', '_model', '_reaction', '_repr_html_', '_set_id_with_model', '_to_json', 'aliases', 'annotation', 'charge', 'compartment', 'compound_id', 'compound_ref', 'constraint', 'copy', 'dblinks', 'elements', 'formula', 'formula_weight', 'from_json', 'id', 'model', 'name', 'notes', 'numerical_attributes', 'reactions', 'remove_from_model', 'shadow_price', 'string_attributes', 'summary', 'y']
# cpd00061_c0
# ===========
# Formula: C3H3O6P
#
# Producing Reactions
# -------------------
# Percent  Flux    Reaction                                Definition
# 100.00% 671.8 rxn33849_c0 cpd29964_c0 <=> cpd00001_c0 + cpd00061_c0
#
# Consuming Reactions
# -------------------
# Percent   Flux    Reaction                                                            Definition
#   0.09% -0.622 rxn00461_c0               cpd00037_c0 + cpd00061_c0 --> cpd00009_c0 + cpd02820_c0
#  23.82%   -160 rxn32421_c0 cpd00001_c0 + cpd00011_c0 + cpd00061_c0 --> cpd00009_c0 + cpd00032_c0
#  76.09% -511.2 rxn35242_c0               cpd00008_c0 + cpd00061_c0 --> cpd00002_c0 + cpd00020_c0

# %%
from periodictable import formula

# print(dir(Formula))

fm = formula('K2SO4 CaSO4 H2O')
print(fm.mass_fraction)
print(fm.atoms)
print(fm.mass)
# Out:
# {K: 0.2381029519107345, S: 0.19527117938676875, O: 0.43845306981640436, Ca: 0.12203459110342926, H: 0.006138207782663331}
# {K: 2, S: 2, O: 9, Ca: 1, H: 2}
# 328.41507999999993

# %%
from numpy import negative
import re

# parse the reaction string
reaction = "(1) cpd00002[0] + (1) cpd00222[0] => (1) cpd00008[0] + (1) cpd00067[0] + (1) cpd00284[0]"
compounds = reaction.split('=>')
reactant, product = compounds[0], compounds[1]
reactants = [x.strip() for x in reactant.split('+')]
products = [x.strip() for x in product.split('+')]
reactant_met = [x.split(' ') for x in reactants]
product_met = [x.split(' ') for x in products]

# assemble a dictionary for the reaction
reaction_dict = {}
for met in reactant_met:
    stoich = float(re.search('(\d+)', met[0]).group())
    met[1] = met[1].replace('[0]', '_c0')
    met[1] = met[1].replace('[1]', '_c0')
    reaction_dict[met[1]] = negative(stoich)
for met in product_met:
    stoich = float(re.search('(\d+)', met[0]).group())
    met[1] = met[1].replace('[0]', '_c0')
    met[1] = met[1].replace('[1]', '_c0')
    reaction_dict[met[1]] = stoich
    

print(reactant_met, product_met)
print(reaction_dict)
# Out:
# [['(1)', 'cpd00002_c0'], ['(1)', 'cpd00222_c0']] [['(1)', 'cpd00008_c0'], ['(1)', 'cpd00067_c0'], ['(1)', 'cpd00284_c0']]
# {'cpd00002_c0': -1.0, 'cpd00222_c0': -1.0, 'cpd00008_c0': 1.0, 'cpd00067_c0': 1.0, 'cpd00284_c0': 1.0}
