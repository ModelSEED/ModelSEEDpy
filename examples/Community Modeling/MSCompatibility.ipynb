# %% [markdown]
# # Load the models

# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the models
import cobrakbase
token = 'WE6CHYRDTJSGOHFIDGPE7WYFT6PRPXJL'
kbase_api = cobrakbase.KBaseAPI(token)
model1 = kbase_api.get_from_ws("iML1515",76994)
model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
# Out:
# cobrakbase 0.2.8
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd11416_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found

# %% [markdown]
# # Align exchange reactions

# %%
# %run ../../modelseedpy/core/mscompatibility.py
mscompat = MSCompatibility(modelseed_db_path = os.path.join('..', '..', '..', 'ModelSEEDDatabase'))

models = [model1, model2]
# model1
before_model_rxns = after_model_rxns = []
for model in models:
    for rxn in model.reactions:
        before_model_rxns.append(rxn.reaction)
    if 'r293_e0' in model.metabolites:
        print('The metabolite r293_e0 is in model', models.index(model))

models = mscompat.correct_exchanges(models, 'exchanges_conflicts.json')

print('\n\n')
for model in models:
    for rxn in model.reactions:
        after_model_rxns.append(rxn.reaction)
    if 'r293_e0' not in model.metabolites:
        print('The metabolite r293_e0 is not in model', models.index(model))
        
for new_rxn in after_model_rxns:
    if new_rxn not in before_model_rxns:
        print('new rxn\t',  new_rxn, 'old rxn\t', before_model_rxns[after_model_rxns.index(new_rxn)])
# Out:
# The metabolite r293_e0 is in model 1
#
#
# {'original': {'id': 'r293', 'name': 'Fe2+'},
#  'new': {'id': 'cpd10515', 'name': 'Fe2+'},
#  'justification': 'The r293 ID is not a ModelSEED Database ID.'}
#
#
#
# The metabolite r293_e0 is not in model 0
# The metabolite r293_e0 is not in model 1

# %% [markdown]
# ## Standardize the models

# %%
# %run ../../modelseedpy/core/mscompatibility.py

model1 = kbase_api.get_from_ws("iML1515",76994)
model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
mscompat = MSCompatibility(modelseed_db_path = os.path.join('..', '..', '..', 'ModelSEEDDatabase'))


models = [model1, model2]
# model1
before_model_rxns = after_model_rxns = []
for model in models:
    for rxn in model.reactions:
        before_model_rxns.append(rxn.reaction)
    if 'r293_e0' in model.metabolites:
        print('The metabolite r293_e0 is in model', models.index(model))
    # if 'prpmn-c_c0' in model.metabolites:
    #     for met in model.metabolites:
    #         if met.id == 'prpmn-c_c0':
    #             print(met.name, met.formula)

# models = mscompat.standardize_MSD(models, output_directory = '')
models = mscompat.standardize_MSD(models, output_directory = '', metabolites = False)

for model in models:
    for rxn in model.reactions:
        after_model_rxns.append(rxn.reaction)
    if 'r293_e0' not in model.metabolites:
        print('The metabolite r293_e0 is not in model', models.index(model))
        
for new_rxn in after_model_rxns:
    if new_rxn not in before_model_rxns:
        print('new rxn\t',  new_rxn, 'old rxn\t', before_model_rxns[after_model_rxns.index(new_rxn)])
# Out:
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd11416_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# WARNING:cobrakbase.core.kbasefba.fbamodel_builder:unable to add sink for [cpd15302_c0]: not found
# The metabolite r293_e0 is in model 1
#
#
# {'original': {'id': 'r293', 'name': 'Fe2+'},
#  'new': {'id': 'cpd10515', 'name': 'Fe2+'},
#  'justification': 'The r293 ID is not a ModelSEED Database ID.'}
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID F6Pt6__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID NAt3__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID GLCtex__DASH__copy2_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID GLCtex__DASH__copy1_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID URIt2pp__DASH__copy2_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ASPt2__DASH__3pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ASPt2__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID TARTt2__DASH__3pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID SUCCt2__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID NAt3__DASH__1p5pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID GAM6Pt6__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ADNt2pp__DASH__copy1_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID CLt3__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID CYTDt2pp__DASH__copy2_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID G6Pt6__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ADNt2pp__DASH__copy2_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MALt2__DASH__3pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID THMDt2pp__DASH__copy2_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID D__DASH__LACt2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID THMDt2pp__DASH__copy1_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MALDt2__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID SUCCt2__DASH__3pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MALt2__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID L__DASH__LACt2rpp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID OROTt2__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID CYTDt2pp__DASH__copy1_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID URIt2pp__DASH__copy1_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID CYTBO3__DASH__4pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MAN6Pt6__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID FUMt2__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID D__DASH__LACtex_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID FUMt2__DASH__3pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID L__DASH__LACtex_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MG2t3__DASH__2pp_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ICHORS__DASH__copy2_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID bio1 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID bio2 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID SK_cpd02701_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:164: UserWarning:
# ModelSEEDError: 2382/4031 reactions were not captured by the ModelSEED modelreaction IDs.
#   print(f'{missed_reactions}/{total_reactions} reactions were not captured by the ModelSEED modelreaction IDs.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__261_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__43_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1662__DASH__ENZRXN3EM__DASH__544__DASH__ENZRXN3EM__DASH__549_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1570_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__117__DASH__ENZRXN3EM__DASH__358_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__507_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__386__DASH__ENZRXN3EM__DASH__888_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__49_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__13_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__14_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__41_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__40_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__43_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__42_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__45_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__44_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__47_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__46_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__27__DASH__MVRXN__DASH__272_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__826_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__283_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__59__DASH__MTRXN__DASH__1_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__828_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__222_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__314_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1498__DASH__ENZRXN3EM__DASH__1512_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__707_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__70_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__75__DASH__MTRXN__DASH__76_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__73_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__72_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1417__DASH__ENZRXN3EM__DASH__264__DASH__ENZRXN3EM__DASH__683__DASH__ENZRXN3EM__DASH__684_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__914_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__12_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1715_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__70_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1713_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1246__DASH__ENZRXN3EM__DASH__727__DASH__ENZRXN3EM__DASH__953__DASH__ENZRXN3EM__DASH__1115_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__513__DASH__ENZRXN3EM__DASH__737_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1172__DASH__ENZRXN3EM__DASH__957__DASH__ENZRXN3EM__DASH__1078_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__388_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__52_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__53_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__50_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__51_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__56_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__57_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__54_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__55_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1508__DASH__MTRXN__DASH__29_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__59_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1574_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__42_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__131__DASH__ENZRXN3EM__DASH__771_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1572_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1571_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1674_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__52_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__43_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__71_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__4716_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1399__DASH__ENZRXN3EM__DASH__319__DASH__ENZRXN3EM__DASH__385__DASH__ENZRXN3EM__DASH__457__DASH__ENZRXN3EM__DASH__477_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__42_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__563_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__77_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__78_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1231_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__28_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__25_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__3924_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1238_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__106__DASH__MVRXN__DASH__117_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__174__DASH__MVRXN__DASH__180_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__178_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1518_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__512__DASH__ENZRXN3EM__DASH__736_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__19_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1339_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__8_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__9_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__1_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__2_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__3_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__4_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__5_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__6_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__7_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__234_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__3415_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__459_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__761_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1295__DASH__ENZRXN3EM__DASH__217_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__175__DASH__MVRXN__DASH__181_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__560__DASH__ENZRXN3EM__DASH__561_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__186_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1446__DASH__ENZRXN3EM__DASH__1523__DASH__ENZRXN3EM__DASH__4702__DASH__ENZRXN3EM__DASH__4715__DASH__MTRXN__DASH__65_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1058_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__70_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__676_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__72_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__73_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__916_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__75_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__76_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__174_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__79_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__228_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1042__DASH__ENZRXN3EM__DASH__188_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__155_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__754_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1664__DASH__MTRXN__DASH__39_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__49_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1631_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1326__DASH__ENZRXN3EM__DASH__1431_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__493__DASH__ENZRXN3EM__DASH__795_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1132__DASH__ENZRXN3EM__DASH__1286_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__134_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1010_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__9_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__4_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__5_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__6_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__7_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__354_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__1_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__2_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__3_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1029__DASH__ENZRXN3EM__DASH__1671_c0 is not captured by the modelreactions.
# ...
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__87_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__86_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__81_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__80_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__83_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MIRXN__DASH__82_e0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1080_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__586_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1547_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__5326__DASH__ENZRXN3EM__DASH__5328_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__4729__DASH__MTRXN__DASH__2_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1197__DASH__ENZRXN3EM__DASH__387_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__32_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__463__DASH__ENZRXN3EM__DASH__499__DASH__ENZRXN3EM__DASH__607_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__3834_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__139_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__138_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__133_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__131_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__130_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__5__DASH__ENZRXN3EM__DASH__856_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__298_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__142_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__785_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__102_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__16_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__17_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__14_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__15_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__12_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__13_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__10_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__11_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__11_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__18_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MERXN__DASH__19_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1536_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__356__DASH__ENZRXN3EM__DASH__703_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1535_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1218_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__912_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1478_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__218_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1049__DASH__ENZRXN3EM__DASH__1630_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MVRXN__DASH__108__DASH__MVRXN__DASH__119_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__3828_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1568_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__399__DASH__ENZRXN3EM__DASH__766_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__44_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__45_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1168_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID ENZRXN3EM__DASH__1020_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__40_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID MTRXN__DASH__41_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:125: UserWarning: ModelSEEDError: The reaction ID SK_cpd11416_c0 is not captured by the modelreactions.
#   warn(f'The reaction ID {rxn.id} is not captured by the modelreactions.')
# C:\Users\Andrew Freiburger\Documents\Argonne\ModelSEEDpy\modelseedpy\core\mscompatibility.py:164: UserWarning:
# ModelSEEDError: 1198/4031 reactions were not captured by the ModelSEED modelreaction IDs.
#   print(f'{missed_reactions}/{total_reactions} reactions were not captured by the ModelSEED modelreaction IDs.')
# The metabolite r293_e0 is not in model 0
# The metabolite r293_e0 is not in model 1

# %%
for met in models[0].metabolites:
    if 'cpd' not in met.id:
        print(met.id)
        for rxn in met.reactions:
            print(rxn.reaction)
        print('\n\n')
# Out:
# sufbcd-4fe4s-c_c0
# 4.0 cpd00067_c0 + sufbcd-4fe4s-c_c0 --> cpd24682_c0 + cpd32553
# 2.0 cpd00067_c0 + cpd00982_c0 + sufbcd-2fe2s2-c_c0 --> cpd00015_c0 + sufbcd-4fe4s-c_c0
#
#
#
# prcp-c_c0
# prpmn-c_c0 --> cpd01024_c0 + prcp-c_c0
# cpd00001_c0 + prcp-c_c0 --> cpd00067_c0 + cpd00847_c0
#
#
#
# 3fe4s-c_c0
# 3fe4s-c_c0 + cpd10515_c0 --> cpd24682_c0
# cpd00025_c0 + 2.0 cpd00067_c0 + 2.0 cpd24682_c0 --> 2.0 3fe4s-c_c0 + 2.0 cpd00001_c0 + 2.0 cpd10516_c0
# 2.0 cpd00067_c0 + 2.0 cpd00418_c0 + 2.0 cpd24682_c0 --> 2.0 3fe4s-c_c0 + cpd00001_c0 + cpd00659_c0 + 2.0 cpd10516_c0
#
#
#
# sufbcd-2fe2s-c_c0
# cpd00001_c0 + cpd00002_c0 + cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 cpd32553 --> cpd00008_c0 + cpd00009_c0 + cpd00015_c0 + 7.0 cpd00067_c0 + sufbcd-2fe2s-c_c0
# 2fe1s-c_c0 + cpd00001_c0 + cpd00002_c0 + cpd32553 --> cpd00008_c0 + cpd00009_c0 + 5.0 cpd00067_c0 + sufbcd-2fe2s-c_c0
# cpd00001_c0 + cpd00002_c0 + cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 cpd32553 + sufbcd-2fe2s-c_c0 --> cpd00008_c0 + cpd00009_c0 + cpd00015_c0 + 7.0 cpd00067_c0 + sufbcd-2fe2s2-c_c0
# 4.0 cpd00067_c0 + sufbcd-2fe2s-c_c0 --> cpd24604_c0 + cpd32553
#
#
#
# rpntp-c_c0
# cpd00002_c0 + cpd25960_c0 --> cpd00128_c0 + rpntp-c_c0
# cpd00001_c0 + rpntp-c_c0 --> cpd00012_c0 + cpd00067_c0 + prpmn-c_c0
#
#
#
# metsox-S-L-c_c0
#
#
#
# metsox-S-L-p_p0
#
#
#
# dhptdd-c_c0
# cpd00010_c0 + dhptdd-c_c0 --> cpd00022_c0 + cpd00095_c0
# dhptdp-c_c0 --> dhptdd-c_c0
#
#
#
# rephaccoa-c_c0
# rephaccoa-c_c0 <=> cpd21214_c0
# cpd00005_c0 + cpd00007_c0 + cpd00067_c0 + cpd00452_c0 --> cpd00001_c0 + cpd00006_c0 + rephaccoa-c_c0
#
#
#
# prpmn-c_c0
# prpmn-c_c0 --> cpd01024_c0 + prcp-c_c0
# cpd00001_c0 + rpntp-c_c0 --> cpd00012_c0 + cpd00067_c0 + prpmn-c_c0
#
#
#
# moadcoo-c_c0
#
#
#
# iscs-c_c0
#
#
#
# sq-e_e0
#
#
#
# sq-c_c0
#
#
#
# ocdceap-c_c0
# cpd00080_c0 + ocdceap-c_c0 --> cpd00009_c0 + cpd00067_c0 + cpd15328_c0
# cpd00001_c0 + ocdceap-c_c0 --> cpd00009_c0 + 2.0 cpd00067_c0 + cpd00536_c0
# cpd00009_c0 + cpd00067_c0 + cpd29680_c0 --> cpd11493_c0 + ocdceap-c_c0
#
#
#
# nadhx-S-c_c0
# cpd00001_c0 + cpd00004_c0 --> nadhx-S-c_c0
# cpd00008_c0 + nadhx-S-c_c0 --> cpd00004_c0 + cpd00009_c0 + cpd00018_c0 + cpd00067_c0
# nadhx-S-c_c0 <=> cpd26514_c0
#
#
#
# gmplys-c_c0
# cpd00001_c0 + gmplys-c_c0 --> cpd00126_c0 + nalme-c_c0
#
#
#
# sla-c_c0
#
#
#
# 2fe1s-c_c0
# 2fe1s-c_c0 + cpd32553 --> 4.0 cpd00067_c0 + iscu-2fe2s-c_c0
# 2fe1s-c_c0 + cpd00001_c0 + cpd00002_c0 + cpd32553 --> cpd00008_c0 + cpd00009_c0 + 5.0 cpd00067_c0 + sufbcd-2fe2s-c_c0
# cpd00017_c0 + cpd01311_c0 + cpd24604_c0 --> 2fe1s-c_c0 + cpd00060_c0 + cpd00067_c0 + cpd00104_c0 + cpd03091_c0
#
#
#
# flxso-c_c0
#
#
#
# dhptdp-c_c0
# cpd00002_c0 + cpd08636_c0 --> cpd00008_c0 + cpd00067_c0 + dhptdp-c_c0
# dhptdp-c_c0 --> dhptdd-c_c0
#
#
#
# sufbcd-c_c0
#
#
#
# dhmpt-c_c0
#
#
#
# metglcur-e_e0
# metglcur-e_e0 <=> metglcur-p_p0
# metglcur-e_e0 <=>
#
#
#
# metglcur-c_c0
# cpd00001_c0 + metglcur-c_c0 --> cpd00116_c0 + cpd00164_c0
# cpd00067_p0 + metglcur-p_p0 --> cpd00067_c0 + metglcur-c_c0
#
#
#
# wco-c_c0
#
#
#
# metglcur-p_p0
# metglcur-e_e0 <=> metglcur-p_p0
# cpd00067_p0 + metglcur-p_p0 --> cpd00067_c0 + metglcur-c_c0
#
#
#
# sqg-c_c0
# cpd00001_c0 + sqg-c_c0 --> cpd00100_c0 + cpd32553
#
#
#
# octapb-c_c0
#
#
#
# bwco-c_c0
#
#
#
# dhps-e_e0
#
#
#
# bwco1gdp-c_c0
# bwco1gdp-c_c0 + cpd00038_c0 + cpd00067_c0 --> cpd00012_c0 + cpd32553
# cpd00038_c0 + cpd00067_c0 + cpd32553 --> bwco1gdp-c_c0 + cpd00012_c0
#
#
#
# dhps-p_p0
#
#
#
# iscu-4fe4s-c_c0
# 4.0 cpd00067_c0 + iscu-4fe4s-c_c0 --> cpd24682_c0 + cpd32553
# 2.0 cpd00067_c0 + cpd00982_c0 + iscu-2fe2s2-c_c0 --> cpd00015_c0 + iscu-4fe4s-c_c0
#
#
#
# sufse-c_c0
#
#
#
# iscu-2fe2s2-c_c0
# cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 cpd32553 + iscu-2fe2s-c_c0 --> cpd00015_c0 + 6.0 cpd00067_c0 + iscu-2fe2s2-c_c0
# 2.0 cpd00067_c0 + cpd00982_c0 + iscu-2fe2s2-c_c0 --> cpd00015_c0 + iscu-4fe4s-c_c0
#
#
#
# bwcogdp-c_c0
#
#
#
# sufsesh-c_c0
#
#
#
# sufbcd-2fe2s2-c_c0
# 2.0 cpd00067_c0 + cpd00982_c0 + sufbcd-2fe2s2-c_c0 --> cpd00015_c0 + sufbcd-4fe4s-c_c0
# cpd00001_c0 + cpd00002_c0 + cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 cpd32553 + sufbcd-2fe2s-c_c0 --> cpd00008_c0 + cpd00009_c0 + cpd00015_c0 + 7.0 cpd00067_c0 + sufbcd-2fe2s2-c_c0
#
#
#
# tartr-D-e_e0
#
#
#
# tartr-D-c_c0
#
#
#
# dhcholn-c_c0
# cpd00003_c0 + cpd00526_c0 --> cpd00004_c0 + cpd00067_c0 + dhcholn-c_c0
#
#
#
# hdcap-c_c0
# cpd00009_c0 + cpd00067_c0 + cpd15277_c0 --> cpd11493_c0 + hdcap-c_c0
# cpd00001_c0 + hdcap-c_c0 --> cpd00009_c0 + 2.0 cpd00067_c0 + cpd00214_c0
# cpd00080_c0 + hdcap-c_c0 --> cpd00009_c0 + cpd00067_c0 + cpd15327_c0
#
#
#
# cdigmp-c_c0
#
#
#
# moadcosh-c_c0
#
#
#
# ddcap-c_c0
# cpd00009_c0 + cpd00067_c0 + cpd11468_c0 --> cpd11493_c0 + ddcap-c_c0
# cpd00080_c0 + ddcap-c_c0 --> cpd00009_c0 + cpd00067_c0 + cpd15325_c0
# cpd00001_c0 + ddcap-c_c0 --> cpd00009_c0 + 2.0 cpd00067_c0 + cpd01741_c0
#
#
#
# 23dhbzs3-c_c0
# cpd00005_c0 + 2.0 fe3dhbzs3-c_c0 --> 2.0 23dhbzs3-c_c0 + cpd00006_c0 + 3.0 cpd00067_c0 + 2.0 cpd10515_c0
#
#
#
# fe3dhbzs3-c_c0
# cpd00005_c0 + 2.0 fe3dhbzs3-c_c0 --> 2.0 23dhbzs3-c_c0 + cpd00006_c0 + 3.0 cpd00067_c0 + 2.0 cpd10515_c0
# cpd00001_c0 + cpd03726_c0 --> fe3dhbzs3-c_c0
# cpd00001_c0 + cpd00002_c0 + fe3dhbzs3-p_p0 --> cpd00008_c0 + cpd00009_c0 + cpd00067_c0 + fe3dhbzs3-c_c0
#
#
#
# fe3dhbzs3-p_p0
# cpd00001_c0 + cpd00002_c0 + fe3dhbzs3-p_p0 --> cpd00008_c0 + cpd00009_c0 + cpd00067_c0 + fe3dhbzs3-c_c0
#
#
#
# lipopb-c_c0
#
#
#
# ampnt-c_c0
#
#
#
# nalme-c_c0
# cpd00001_c0 + gmplys-c_c0 --> cpd00126_c0 + nalme-c_c0
#
#
#
# 14dhncoa-c_c0
# cpd00067_c0 + cpd02021_c0 --> 14dhncoa-c_c0 + cpd00001_c0
# 14dhncoa-c_c0 + cpd00001_c0 --> cpd00010_c0 + cpd00067_c0 + cpd02295_c0
#
#
#
# apoACP-c_c0
#
#
#
# iscu-c_c0
#
#
#
# hdceap-c_c0
# cpd00001_c0 + hdceap-c_c0 --> cpd00009_c0 + 2.0 cpd00067_c0 + cpd15237_c0
# cpd00080_c0 + hdceap-c_c0 --> cpd00009_c0 + cpd00067_c0 + cpd15326_c0
# cpd00009_c0 + cpd00067_c0 + cpd15239_c0 --> cpd11493_c0 + hdceap-c_c0
#
#
#
# gslnt-c_c0
#
#
#
# ttdcap-c_c0
# cpd00080_c0 + ttdcap-c_c0 --> cpd00009_c0 + cpd00067_c0 + cpd15331_c0
# cpd00001_c0 + ttdcap-c_c0 --> cpd00009_c0 + 2.0 cpd00067_c0 + cpd03847_c0
# cpd00009_c0 + cpd00067_c0 + cpd27551_c0 --> cpd11493_c0 + ttdcap-c_c0
#
#
#
# bmoco1gdp-c_c0
# cpd00038_c0 + cpd00067_c0 + cpd19503 --> bmoco1gdp-c_c0 + cpd00012_c0
# bmoco1gdp-c_c0 + cpd00038_c0 + cpd00067_c0 --> cpd00012_c0 + cpd37287
#
#
#
# opmeACP-c_c0
# cpd00005_c0 + cpd00067_c0 + opmeACP-c_c0 --> cpd00006_c0 + cpd22065_c0
# cpd00067_c0 + cpd11492_c0 + cpd27180_c0 --> cpd00011_c0 + cpd11493_c0 + opmeACP-c_c0
#
#
#
# puacgam-c_c0
# puacgam-c_c0 --> puacgam-p_p0
# cpd00014_c0 + puacgam-c_c0 <=> cpd00037_c0
#
#
#
# moadamp-c_c0
#
#
#
# puacgam-p_p0
# puacgam-c_c0 --> puacgam-p_p0
#
#
#
# cxsam-c_c0
# cpd00017_c0 + cpd00219_c0 --> cpd00001_c0 + cpd00143_c0 + cxsam-c_c0
#
#
#
# iscu-2fe2s-c_c0
# cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 cpd32553 + iscu-2fe2s-c_c0 --> cpd00015_c0 + 6.0 cpd00067_c0 + iscu-2fe2s2-c_c0
# 2fe1s-c_c0 + cpd32553 --> 4.0 cpd00067_c0 + iscu-2fe2s-c_c0
# cpd00982_c0 + 2.0 cpd10515_c0 + 2.0 cpd32553 --> cpd00015_c0 + 6.0 cpd00067_c0 + iscu-2fe2s-c_c0
# 4.0 cpd00067_c0 + iscu-2fe2s-c_c0 --> cpd24604_c0 + cpd32553
#
#
#
# ttdceap-c_c0
# cpd00001_c0 + ttdceap-c_c0 --> cpd00009_c0 + 2.0 cpd00067_c0 + cpd15298_c0
# cpd00080_c0 + ttdceap-c_c0 --> cpd00009_c0 + cpd00067_c0 + cpd15330_c0
# cpd00009_c0 + cpd00067_c0 + cpd15294_c0 --> cpd11493_c0 + ttdceap-c_c0
#
#
#
# 2ddglcn-c_c0
# cpd00403_c0 --> 2ddglcn-c_c0 + cpd00001_c0
# cpd00067_p0 + cpd00176_p0 <=> 2ddglcn-c_c0 + cpd00067_c0
# cpd00608_c0 --> 2ddglcn-c_c0 + cpd00001_c0
# 2ddglcn-c_c0 + cpd00002_c0 --> cpd00008_c0 + cpd00067_c0 + cpd02711_c0
#
#
#
# metsox-R-L-c_c0
#
#
#
# metsox-R-L-e_e0
#
#
#
# 4abzglu-c_c0
#
#
#
# ogmeACP-c_c0
# cpd00067_c0 + cpd11492_c0 + cpd20921_c0 --> cpd00010_c0 + cpd00011_c0 + ogmeACP-c_c0
# cpd00005_c0 + cpd00067_c0 + ogmeACP-c_c0 --> cpd00006_c0 + cpd22022_c0
#
#
#
# 4abzglu-p_p0
#
#
#
# ocdcap-c_c0
# cpd00080_c0 + ocdcap-c_c0 --> cpd00009_c0 + cpd00067_c0 + cpd15329_c0
# cpd00001_c0 + ocdcap-c_c0 --> cpd00009_c0 + 2.0 cpd00067_c0 + cpd01080_c0
# cpd00009_c0 + cpd00067_c0 + cpd12458 --> cpd11493_c0 + ocdcap-c_c0
#
#
#
# iscssh-c_c0
#
#
#
# mocogdp-c_c0
#
#
#
# colipap-p_p0
#
#
#
# colipap-e_e0

# %% [markdown]
# # Brainstorming

# %%
print(sum(rxn for model in models for rxn in model.reactions))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 print(sum(rxn for model in models for rxn in model.reactions))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\reaction.py:967, in Reaction.__add__(self, other)
#     947 def __add__(self, other: "Reaction") -> "Reaction":
#     948     """Add two reactions and return a new one.
#     949
#     950     The stoichiometry will be the combined stoichiometry of the two
#    (...)
#     965
#     966     """
# --> 967     new_reaction = self.copy()
#     968     if other == 0:
#     969         return new_reaction
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\reaction.py:938, in Reaction.copy(self)
#     936     i._model = None
#     937 # now we can copy
# --> 938 new_reaction = deepcopy(self)
#     939 # restore the references
#     940 self._model = model
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\reaction.py:273, in Reaction.__deepcopy__(self, memo)
#     260 def __deepcopy__(self, memo: dict) -> "Reaction":
#     261     """Copy the reaction with memo.
#     262
#     263     Parameters
#    (...)
#     271         A new reaction that is a deep copy of the original reaction with memo.
#     272     """
# --> 273     cop = deepcopy(super(Reaction, self), memo)
#     274     return cop
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
#     [... skipping similar frames: deepcopy at line 146 (14 times), _deepcopy_dict at line 230 (13 times), _reconstruct at line 270 (13 times), deepcopy at line 172 (13 times)]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
#     [... skipping similar frames: deepcopy at line 146 (2 times), _deepcopy_dict at line 230 (1 times), _reconstruct at line 270 (1 times), deepcopy at line 172 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
#     [... skipping similar frames: deepcopy at line 146 (5 times), _deepcopy_dict at line 230 (3 times), _reconstruct at line 270 (3 times), deepcopy at line 172 (3 times), _deepcopy_list at line 205 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
#     [... skipping similar frames: deepcopy at line 172 (1 times)]
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:270, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268 if state is not None:
#     269     if deep:
# --> 270         state = deepcopy(state, memo)
#     271     if hasattr(y, '__setstate__'):
#     272         y.__setstate__(state)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\copy.py:258, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     254     except KeyError:
#     255         # aha, this is the first one :-)
#     256         memo[id(memo)]=[x]
# --> 258 def _reconstruct(x, memo, func, args,
#     259                  state=None, listiter=None, dictiter=None,
#     260                  deepcopy=deepcopy):
#     261     deep = memo is not None
#     262     if deep and args:
#
# KeyboardInterrupt:

# %%
pfba, self_pfba = None, False
if pfba == None or self_pfba == None:
    print('yes')

# %%
if 'cpd00035' in model1.metabolites:
    print('not replaced')

# %%
# model1 = kbase_api.get_from_ws("iML1515",76994)
# model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
import re

for rxn in model1.reactions:
    pprint(rxn.id)
    break

for rxn in model1.modelreactions:
    pprint(rxn)
    if 3 == model1.modelreactions.index(rxn):
        break
    # print(rxn.reactants)
    # print(rxn.products, '\n\n')
    # for index, met_id in enumerate([re.sub('_\w\d', '', met.id) for met in rxn.reactants]):
    #     if met_id in [re.sub('_\w\d', '', met.id) for met in rxn.products]:
    #         print(rxn.metabolites[rxn.reactants[index]])
    #         print(rxn)
    #         break
            
# # exclude reactions where the erroneous ID is both a reactant and product (which is currently an evasive condition)
# for met_id in [re.sub('_\w\d', '', react_met.id) for react_met in rxn.reactants]:
#     print(met_id)
#     if met_id in [re.sub('_\w\d', '', pro_met.id) for pro_met in rxn.products] and met_id == original_id:
#         warn(f'ReactionError: The {met.id} metabolite in the {rxn.id} reaction cannot be substituted as both a reactant and product.')
#         continue
# Out:
# '34dhpactex_e0'
# {'aliases': [],
#  'dblinks': {},
#  'direction': '=',
#  'id': 'R-34dhpactex_e0',
#  'imported_gpr': '(b1377 or b0241 or b0929 or b2215)',
#  'maxforflux': 1000.0,
#  'maxrevflux': 1000.0,
#  'modelReactionProteins': [{'complex_ref': '',
#                             'modelReactionProteinSubunits': [{'feature_refs': ['23938/40/4/features/id/b0929',
#                                                                                '23938/40/4/features/id/b2215',
#                                                                                '23938/40/4/features/id/b1377',
#                                                                                '23938/40/4/features/id/b0241'],
#                                                               'note': 'Imported '
#                                                                       'GPR',
#                                                               'optionalSubunit': 0,
#                                                               'role': '',
#                                                               'triggering': 0}],
#                             'note': 'Imported GPR',
#                             'source': ''}],
#  'modelReactionReagents': [{'coefficient': -1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd02500_e0'},
#                            {'coefficient': 1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd02500_p0'}],
#  'modelcompartment_ref': '~/modelcompartments/id/p0',
#  'name': 'Dihydroxyphenylacetaldehyde transport via diffusion (extracellular '
#          'to periplasm)',
#  'probability': 0.0,
#  'protons': 0.0,
#  'reaction_ref': '~/template/reactions/id/rxn00000_c',
#  'string_attributes': {'original_id': 'R_34dhpactex'}}
# {'aliases': [],
#  'dblinks': {},
#  'direction': '=',
#  'id': 'R-GUAtex_e0',
#  'imported_gpr': 'b0411',
#  'maxforflux': 1000.0,
#  'maxrevflux': 1000.0,
#  'modelReactionProteins': [{'complex_ref': '',
#                             'modelReactionProteinSubunits': [{'feature_refs': ['23938/40/4/features/id/b0411'],
#                                                               'note': 'Imported '
#                                                                       'GPR',
#                                                               'optionalSubunit': 0,
#                                                               'role': '',
#                                                               'triggering': 0}],
#                             'note': 'Imported GPR',
#                             'source': ''}],
#  'modelReactionReagents': [{'coefficient': -1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00207_e0'},
#                            {'coefficient': 1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00207_p0'}],
#  'modelcompartment_ref': '~/modelcompartments/id/p0',
#  'name': 'Guanine transport via diffusion (extracellular to periplasm)',
#  'probability': 0.0,
#  'protons': 0.0,
#  'reaction_ref': '~/template/reactions/id/rxn00000_c',
#  'string_attributes': {'original_id': 'R_GUAtex'}}
# {'aliases': [],
#  'dblinks': {'BiGG': ['CHORM'],
#              'LigandReaction': ['R01715'],
#              'MetaCyc': ['META:CHORISMATEMUT-RXN'],
#              'ModelSeedReaction': ['rxn01256'],
#              'Seed': ['rxn01256']},
#  'direction': '>',
#  'id': 'rxn01256_c0',
#  'imported_gpr': '(b2599 or b2600)',
#  'maxforflux': 1000.0,
#  'maxrevflux': 0.0,
#  'modelReactionProteins': [{'complex_ref': '',
#                             'modelReactionProteinSubunits': [{'feature_refs': ['23938/40/4/features/id/b2600',
#                                                                                '23938/40/4/features/id/b2599'],
#                                                               'note': 'Imported '
#                                                                       'GPR',
#                                                               'optionalSubunit': 0,
#                                                               'role': '',
#                                                               'triggering': 0}],
#                             'note': 'Imported GPR',
#                             'source': ''}],
#  'modelReactionReagents': [{'coefficient': -1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00216_c0'},
#                            {'coefficient': 1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00219_c0'}],
#  'modelcompartment_ref': '~/modelcompartments/id/c0',
#  'name': 'Chorismate pyruvatemutase_c0',
#  'probability': 0.0,
#  'protons': 0.0,
#  'reaction_ref': '~/template/reactions/id/rxn01256_c',
#  'string_attributes': {'original_id': 'R_CHORM'}}
# {'aliases': [],
#  'dblinks': {'LigandReaction': ['R00572'],
#              'ModelSeedReaction': ['rxn00411'],
#              'Seed': ['rxn00411']},
#  'direction': '>',
#  'id': 'rxn00411_c0',
#  'imported_gpr': 'b1854',
#  'maxforflux': 1000.0,
#  'maxrevflux': 0.0,
#  'modelReactionProteins': [{'complex_ref': '',
#                             'modelReactionProteinSubunits': [{'feature_refs': ['23938/40/4/features/id/b1854'],
#                                                               'note': 'Imported '
#                                                                       'GPR',
#                                                               'optionalSubunit': 0,
#                                                               'role': '',
#                                                               'triggering': 0}],
#                             'note': 'Imported GPR',
#                             'source': ''}],
#  'modelReactionReagents': [{'coefficient': -1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00096_c0'},
#                            {'coefficient': -1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00067_c0'},
#                            {'coefficient': -1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00061_c0'},
#                            {'coefficient': 1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00052_c0'},
#                            {'coefficient': 1.0,
#                             'modelcompound_ref': '~/modelcompounds/id/cpd00020_c0'}],
#  'modelcompartment_ref': '~/modelcompartments/id/c0',
#  'name': 'CTP:pyruvate 2-O-phosphotransferase_c0',
#  'probability': 0.0,
#  'protons': 0.0,
#  'reaction_ref': '~/template/reactions/id/rxn00411_c',
#  'string_attributes': {'original_id': 'R_PYK4'}}

# %%
from cobra.core.dictlist import DictList

test = DictList()
test.append({'a':4, 'b':5})
print(test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       1 from cobra.core.dictlist import DictList
#       3 test = DictList()
# ----> 4 test.append({'a':4, 'b':5})
#       5 print(test)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\dictlist.py:180, in DictList.append(self, entity)
#     178 def append(self, entity: Object) -> None:
#     179     """Append object to end."""
# --> 180     the_id = entity.id
#     181     self._check(the_id)
#     182     self._dict[the_id] = len(self)
#
# AttributeError: 'dict' object has no attribute 'id'

# %%
from collections import OrderedDict

x = OrderedDict({'x':2, 'c':4})
x.pop('c')
print(x)
print(list(x.keys()).index('x'))
print(dir(x))

# %%
print(model1.annotation)
# print(dir(model1))

# for met in model.metabolites:
#     print(dir(met))
#     print(met.summary())
#     if met == model.metabolites[4]:
#         break
        
for rxn in model1.modelcompounds:
    pprint(rxn)
    if 3 == model1.modelcompounds.index(rxn):
        break
# Out:
# {}
# {'charge': 1.0,
#  'compound_ref': '~/template/compounds/id/cpd01911',
#  'dblinks': {'BiGG': ['Nmtrp'],
#              'BiGG2': ['Nmtrp'],
#              'LigandCompound': ['C02983'],
#              'MetaCyc': ['META:N-METHYLTRYPTOPHAN'],
#              'MetaNetX': ['MNXM3055'],
#              'ModelSeed': ['cpd01911'],
#              'Seed': ['cpd15389']},
#  'formula': 'C12H14N2O2',
#  'id': 'cpd01911_c0',
#  'modelcompartment_ref': '~/modelcompartments/id/c0',
#  'name': 'Abrine_c0',
#  'string_attributes': {'boundary_condition': 'false',
#                        'original_id': 'M_Nmtrp_c'}}
# {'charge': 1.0,
#  'compound_ref': '~/template/compounds/id/cpd00242',
#  'dblinks': {'BiGG': ['hco3'],
#              'BiGG2': ['hco3'],
#              'HMDB': ['HMDB00595'],
#              'LigandCompound': ['C00288'],
#              'MetaCyc': ['META:HCO3'],
#              'MetaNetX': ['MNXM60'],
#              'ModelSeed': ['cpd00242'],
#              'Seed': ['cpd00242']},
#  'formula': 'CHO3',
#  'id': 'cpd00242_c0',
#  'modelcompartment_ref': '~/modelcompartments/id/c0',
#  'name': 'H2CO3_c0',
#  'string_attributes': {'boundary_condition': 'false',
#                        'original_id': 'M_hco3_c'}}
# {'charge': 1.0,
#  'compound_ref': '~/template/compounds/id/cpd15510',
#  'dblinks': {'BiGG': ['murein5p4p'],
#              'BiGG2': ['murein5p4p'],
#              'MetaCyc': ['META:CPD0-2245'],
#              'MetaNetX': ['MNXM5971'],
#              'ModelSeed': ['cpd15510'],
#              'Seed': ['cpd15510']},
#  'formula': 'C77H119N15O41',
#  'id': 'cpd15510_p0',
#  'modelcompartment_ref': '~/modelcompartments/id/p0',
#  'name': 'two linked disacharide pentapeptide and tetrapeptide murein units '
#          '(uncrosslinked, middle of chain)_p0',
#  'string_attributes': {'boundary_condition': 'false',
#                        'original_id': 'M_murein5p4p_p'}}
# {'charge': 1.0,
#  'compound_ref': '~/template/compounds/id/cpd00196',
#  'dblinks': {'BiGG': ['actp'],
#              'BiGG2': ['actp'],
#              'HMDB': ['HMDB01494'],
#              'LigandCompound': ['C00227'],
#              'MetaCyc': ['META:ACETYL-P'],
#              'MetaNetX': ['MNXM280'],
#              'ModelSeed': ['cpd00196'],
#              'Seed': ['cpd00196']},
#  'formula': 'C2H3O5P',
#  'id': 'cpd00196_c0',
#  'modelcompartment_ref': '~/modelcompartments/id/c0',
#  'name': 'Acetylphosphate_c0',
#  'string_attributes': {'boundary_condition': 'false',
#                        'original_id': 'M_actp_c'}}

# %%
from periodictable import formula

# print(dir(Formula))

fm = formula('K2SO4 CaSO4 H2O')
print(fm.mass_fraction)
print(fm.atoms)
print(fm.mass)
# Out:
# {K: 0.2381029519107345, S: 0.19527117938676875, O: 0.43845306981640436, Ca: 0.12203459110342926, H: 0.006138207782663331}
# {K: 2, S: 2, O: 9, Ca: 1, H: 2}
# 328.41507999999993

# %%
from numpy import negative
import re

# parse the reaction string
reaction = "(1) cpd00002[0] + (1) cpd00222[0] => (1) cpd00008[0] + (1) cpd00067[0] + (1) cpd00284[0]"
compounds = reaction.split('=>')
reactant, product = compounds[0], compounds[1]
reactants = [x.strip() for x in reactant.split('+')]
products = [x.strip() for x in product.split('+')]
reactant_met = [x.split(' ') for x in reactants]
product_met = [x.split(' ') for x in products]

# assemble a dictionary for the reaction
reaction_dict = {}
for met in reactant_met:
    stoich = float(re.search('(\d+)', met[0]).group())
    met[1] = met[1].replace('[0]', '_c0')
    met[1] = met[1].replace('[1]', '_c0')
    reaction_dict[met[1]] = negative(stoich)
for met in product_met:
    stoich = float(re.search('(\d+)', met[0]).group())
    met[1] = met[1].replace('[0]', '_c0')
    met[1] = met[1].replace('[1]', '_c0')
    reaction_dict[met[1]] = stoich
    

print(reactant_met, product_met)
print(reaction_dict)
# Out:
# [['(1)', 'cpd00002_c0'], ['(1)', 'cpd00222_c0']] [['(1)', 'cpd00008_c0'], ['(1)', 'cpd00067_c0'], ['(1)', 'cpd00284_c0']]
# {'cpd00002_c0': -1.0, 'cpd00222_c0': -1.0, 'cpd00008_c0': 1.0, 'cpd00067_c0': 1.0, 'cpd00284_c0': 1.0}
