# %% [markdown]
# # Load the model

# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the models
import cobrakbase
with open("C:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase_api = cobrakbase.KBaseAPI(token_file.readline())
model1 = kbase_api.get_from_ws("E_iAH991V2",40576)
model2 = kbase_api.get_from_ws("E_iML1515.kb",40576)
models = [model1, model2]
com_model = kbase_api.get_from_ws("CMM_iAH991V2_iML1515.kb",40576)

# prevent excessive warnings
import warnings
warnings.filterwarnings(action='once')
# %run ../../modelseedpy/community/mssmetana.py

from time import process_time
# Out:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# cobrakbase 0.2.8

# %% [markdown]
# # Class methods

# %%
start_time = process_time()
import json
smetana_scores = MSSmetana(models, com_model)

smetana_scores.mro_score()
smetana_scores.mip_score(interacting_media=smetana_scores.media)
smetana_scores.mu_score()
smetana_scores.mp_score()
smetana_scores.sc_score()
smetana_scores.smetana_score();
# Out:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# Community models are too excessive for direct assessment via the JENGA method; thus, the community minimal media is estimated as the combination of member media.
# Syntrophic fluxes examined after 0.0 minutes, with 2 change(s): {'dictionary_item_removed': [root['EX_cpd00009_e0'], root['EX_cpd10515_e0']]}
# ...

# %% [markdown]
# # Static methods

# %%
 from pprint import pprint
import json

print("MRO score: ", MSSmetana.mro(models))
print("\n\n\nMIP score: ", MSSmetana.mip(models))
print("\n\n\nMU score: ") ; pprint(MSSmetana.mu(models))
print("\n\n\nMP score: ") ; pprint([{model:exchanges} for model, exchanges in MSSmetana.mp(models, com_model).items()])
print("\n\n\nSC score: ") ; pprint(MSSmetana.sc(models, com_model))
print("\n\n\nsmetana score: ") ; pprint(MSSmetana.smetana(models, com_model))

end_time = process_time()
print(f"The Notebook completely executed in {(end_time-start_time)/60} minutes.")
# Out:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\medium\minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# {(<FBAModel Bacteroides_thetaiotaomicron_VPI-5482.fbamdl.23 at 0x236d746e2b0>, <FBAModel iML1515 at 0x236d7f7e550>): {'EX_cpd00030_e0',
#                                                                                                                       'EX_cpd00034_e0',
# ...
