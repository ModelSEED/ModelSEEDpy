# %%
# import kbase
import os
local_cobrakbase_path = 'C:\\Users\\Andrew Freiburger\\Dropbox\\My PC (DESKTOP-M302P50)\\Documents\\UVic Civil Engineering\\Internships\\Agronne\\cobrakbase'
os.environ["HOME"] = local_cobrakbase_path
import cobrakbase
token = 'JOSNYJGASTV5BGELWQTUSATE4TNHZ66U'
kbase = cobrakbase.KBaseAPI(token)
import networkx
from matplotlib import pyplot

ftp_path = '../../../ModelSEEDDatabase'

# import cFBA
# %run ../../modelseedpy/core/mscommunity.py
# %matplotlib inline
# Out:
# cobrakbase 0.2.8

# %% [markdown]
# # 2-member Zahmeeth model

# %% [markdown]
# ### sans kinetic constraints

# %%
modelInfo_2 = ["CMM_iAH991V2_iML1515.kb",40576]
mediaInfo_2 = ["Btheta_Ecoli_minimal_media",40576]
model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])

# simulate and visualize the model
cfba = MSCommunity(model)
cfba.drain_fluxes(media)
cfba.gapfill(media)
cfba.constrain(media)#, kinetic_coeff=2100, abundances={"1":0.5,"2":0.5})
solution = cfba.run()
cfba.compute_interactions(solution)
cfba.visualize()
# Out:
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
#
# Model objective value: 0.17375024029002192
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000
# (<networkx.classes.graph.Graph at 0x7fa2419d1310>,
#  {1: array([1.00000000e+00, 4.37113883e-08]),
#   2: array([-1.00000000e+00, -4.37113883e-08])},
#  {(1, 2): '-409'})

# %% [markdown]
# ### variable kinetic coefficients

# %%
modelInfo_2 = ["CMM_iAH991V2_iML1515.kb",40576]
mediaInfo_2 = ["Btheta_Ecoli_minimal_media",40576]

model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
abundances = {"1":0.5,"2":0.5}

# evaluate the influence of kinetic constraints over a range of coefficients
plots = []
for kinetic_coeff in range(800,1400,50):
    banner = '\n{}\nKinetic coefficient: {}'.format('='*50, kinetic_coeff)
    print(banner)
    
    model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
    media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
    cfba = MSCommunity(model)
    cfba.drain_fluxes(media)
    cfba.gapfill(media)

    cfba.constrain(media, kinetic_coeff = kinetic_coeff, abundances = abundances)
    solution = cfba.run()
    cfba.compute_interactions(solution)
    graph, pos, labels = cfba.visualize()
    plots.append((graph, pos, labels, banner))
# Out:
# ==================================================
# Kinetic coefficient: 800
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.0
#
#
#
# Production matrix:
#          1    2
# Donor
# 1      0.0  0.0
# 2      0.0  0.0
#
#
# Consumption matrix:
#             1    2
# Receiver
# 1         0.0  0.0
# 2         0.0  0.0
# ==================================================
# Kinetic coefficient: 850
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.0
#
#
#
# Production matrix:
#          1    2
# Donor
# 1      0.0  0.0
# 2      0.0  0.0
#
#
# Consumption matrix:
#             1    2
# Receiver
# 1         0.0  0.0
# 2         0.0  0.0
# ==================================================
# Kinetic coefficient: 900
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.021334885615539135
#
#
#
# Production matrix:
#               1         2
# Donor
# 1      0.000000  0.824103
# 2      0.554976  0.000000
#
#
# Consumption matrix:
#                  1         2
# Receiver
# 1         0.000000  0.554976
# 2         0.824103  0.000000
# ==================================================
# Kinetic coefficient: 950
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.06659926817439696
#
#
#
# Production matrix:
#               1         2
# Donor
# 1      0.000000  2.516788
# 2      1.150394  0.000000
#
#
# Consumption matrix:
#                  1         2
# Receiver
# 1         0.000000  1.150394
# 2         2.516788  0.000000
# ==================================================
# Kinetic coefficient: 1000
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.10644330952285178
#
#
#
# Production matrix:
#               1         2
# Donor
# 1      0.000000  2.735416
# 2      1.471245  0.000000
#
#
# Consumption matrix:
#                  1         2
# Receiver
# 1         0.000000  1.471245
# 2         2.735416  0.000000
# ==================================================
# Kinetic coefficient: 1050
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.14034169325907905
#
#
#
# Production matrix:
#               1         2
# Donor
# 1      0.000000  3.351431
# 2      2.090847  0.000000
#
#
# Consumption matrix:
#                  1         2
# Receiver
# 1         0.000000  2.090847
# 2         3.351431  0.000000
# ==================================================
# Kinetic coefficient: 1100
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.1582645871783188
#
#
#
# Production matrix:
#                 1         2
# Donor
# 1        0.000000  8.491107
# 2      114.739419  0.000000
#
#
# Consumption matrix:
#                  1           2
# Receiver
# 1         0.000000  114.739419
# 2         8.491107    0.000000
# ==================================================
# Kinetic coefficient: 1150
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.16605214307254668
#
#
#
# Production matrix:
#              1          2
# Donor
# 1        0.000  11.906086
# 2      215.854   0.000000
#
#
# Consumption matrix:
#                   1        2
# Receiver
# 1          0.000000  215.854
# 2         11.906086    0.000
# ==================================================
# Kinetic coefficient: 1200
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17099340636619656
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  14.145939
# 2      299.445369   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  299.445369
# 2         14.145939    0.000000
# ==================================================
# Kinetic coefficient: 1250
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17281778268948225
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  15.840874
# 2      391.318146   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  391.318146
# 2         15.840874    0.000000
# ==================================================
# Kinetic coefficient: 1300
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17373273688922833
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  17.920557
# 2      442.582945   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  442.582945
# 2         17.920557    0.000000
# ==================================================
# Kinetic coefficient: 1350
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17375024029002095
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000

# %% [markdown]
# ### variable abundances

# %%
modelInfo_2 = ["CMM_iAH991V2_iML1515.kb",40576]
mediaInfo_2 = ["Btheta_Ecoli_minimal_media",40576]
model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
kinetic_coeff = 2000

# evaluate the influence of kinetic constraints over a range of coefficients
plots = []
for abundance in range(0, 10):
    species_1 = abundance/10   # B. Theta
    species_2 = 1-species_1    # E. coli
    banner = '\n{}\nAbundance\nspecies 1:{}\tspecies 2:{}'.format('='*30, species_1, species_2)
    print(banner)
    model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
    media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
    cfba = MSCommunity(model)
    cfba.drain_fluxes(media)
    cfba.gapfill(media)

    cfba.constrain(media, kinetic_coeff = kinetic_coeff, abundances = {"1":species_1,"2":species_2})
    solution = cfba.run()
    cfba.compute_interactions(solution)
    graph, pos, labels = cfba.visualize()
    plots.append((graph, pos, labels, banner))
# Out:
# ==============================
# Abundance
# species 1:0.0	species 2:1.0
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.16324578220864486
#
#
#
# Production matrix:
#               1         2
# Donor
# 1      0.000000  0.295723
# 2      0.273455  0.000000
#
#
# Consumption matrix:
#                  1         2
# Receiver
# 1         0.000000  0.273455
# 2         0.295723  0.000000
# ==============================
# Abundance
# species 1:0.1	species 2:0.9
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.1697249159764732
#
#
#
# Production matrix:
#                 1         2
# Donor
# 1        0.000000  7.564981
# 2      161.319245  0.000000
#
#
# Consumption matrix:
#                  1           2
# Receiver
# 1         0.000000  161.319245
# 2         7.564981    0.000000
# ==============================
# Abundance
# species 1:0.2	species 2:0.8
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17307252967635806
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  17.203222
# 2      373.667976   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  373.667976
# 2         17.203222    0.000000
# ==============================
# Abundance
# species 1:0.3	species 2:0.7
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17348609597492723
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  14.376352
# 2      390.376437   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  390.376437
# 2         14.376352    0.000000
# ==============================
# Abundance
# species 1:0.4	species 2:0.6
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17361806766456336
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  16.223842
# 2      413.067003   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  413.067003
# 2         16.223842    0.000000
# ==============================
# Abundance
# species 1:0.5	species 2:0.5
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17375024029002165
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000
# ==============================
# Abundance
# species 1:0.6	species 2:0.4
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.17388261431056012
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  20.321907
# 2      441.118883   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  441.118883
# 2         20.321907    0.000000
# ==============================
# Abundance
# species 1:0.7	species 2:0.30000000000000004
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.1740151901868401
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  22.356352
# 2      454.507051   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  454.507051
# 2         22.356352    0.000000
# ==============================
# Abundance
# species 1:0.8	species 2:0.19999999999999996
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.16907396310469391
#
#
#
# Production matrix:
#                 1        2
# Donor
# 1        0.000000  24.8125
# 2      393.753979   0.0000
#
#
# Consumption matrix:
#                 1           2
# Receiver
# 1          0.0000  393.753979
# 2         24.8125    0.000000
# ==============================
# Abundance
# species 1:0.9	species 2:0.09999999999999998
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.1743969883599168
# species 2 drain-flux objective value: 0.16925387417839677
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio4
#
# Model objective value: 0.15027524186203697
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  24.811095
# 2      393.800474   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  393.800474
# 2         24.811095    0.000000

# %% [markdown]
# # 3-member Electrosynth model

# %% [markdown]
# ### sans kinetic constraints

# %%
import networkx

# %run ../../modelseedpy/core/mscommunity.py
modelInfo = ["electro.community.edited.v2",93204]
mediaInfo = ["CO2_minimal",93204]
model = kbase.get_from_ws(modelInfo[0],modelInfo[1])
media = kbase.get_from_ws(mediaInfo[0],mediaInfo[1])

# simulate and visualize the model
cfba = MSCommunity(model)
cfba.drain_fluxes(media)
cfba.gapfill(media)
cfba.constrain(media)#, kinetic_coeff=2100, abundances={"1":0.5,"2":0.5})
solution = cfba.run()
cfba.compute_interactions(solution)
cfba.visualize()
# Out:
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
#
# Model objective value: 0.12453728378574319
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.110895  0.383884
# 2      1.257597  0.000000  0.253042
# 3      1.554671  2.139689  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  1.257597  1.554671
# 2         0.110895  0.000000  2.139689
# 3         0.383884  0.253042  0.000000
# (<networkx.classes.graph.Graph at 0x7fa1e124f280>,
#  {1: array([1.00000000e+00, 1.98682151e-08]),
#   2: array([-0.50000007,  0.86602542]),
#   3: array([-0.49999993, -0.86602544])},
#  {(1, 2): '-1.15', (1, 3): '-1.17', (2, 3): '-1.89'})

# %% [markdown]
# ### variable kinetic coefficients

# %%
modelInfo = ["electro.community.edited.v2",93204]
mediaInfo = ["CO2_minimal",93204]
model = kbase.get_from_ws(modelInfo[0],modelInfo[1])
media = kbase.get_from_ws(mediaInfo[0],mediaInfo[1])
abundances = {"1":0.5,"2":0.5}

# evaluate the influence of kinetic constraints over a range of coefficients
plots = []
for kinetic_coeff in range(800,1400,50):
    banner = '\n{}\nKinetic coefficient: {}'.format('='*50, kinetic_coeff)
    print(banner)
    
    model = kbase.get_from_ws(modelInfo[0],modelInfo[1])
    media = kbase.get_from_ws(mediaInfo[0],mediaInfo[1])
    cfba = MSCommunity(model)
    cfba.drain_fluxes(media)
    cfba.gapfill(media)
    
    cfba.constrain(media, kinetic_coeff = kinetic_coeff, abundances = abundances)
    solution = cfba.run()
    cfba.compute_interactions(solution)
    graph, pos, labels = cfba.visualize()
    plots.append((graph, pos, labels, banner))
# Out:
# ==================================================
# Kinetic coefficient: 800
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.07079560936880114
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.326093  0.486814
# 2      1.695546  0.000000  0.826021
# 3      0.000157  2.310370  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  1.695546  0.000157
# 2         0.326093  0.000000  2.310370
# 3         0.486814  0.826021  0.000000
# ==================================================
# Kinetic coefficient: 850
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661113
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  1.036769  0.407606
# 2      2.521830  0.000000  0.509923
# 3      0.000236  1.774988  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.521830  0.000236
# 2         1.036769  0.000000  1.774988
# 3         0.407606  0.509923  0.000000
# ==================================================
# Kinetic coefficient: 900
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661088
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.861631  0.407606
# 2      2.348143  0.000000  0.509923
# 3      0.000203  1.958571  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.348143  0.000203
# 2         0.861631  0.000000  1.958571
# 3         0.407606  0.509923  0.000000
# ==================================================
# Kinetic coefficient: 950
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661145
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.678048  0.407606
# 2      2.348143  0.000000  0.509923
# 3      0.000203  2.142155  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.348143  0.000203
# 2         0.678048  0.000000  2.142155
# 3         0.407606  0.509923  0.000000
# ==================================================
# Kinetic coefficient: 1000
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661214
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.494464  0.407606
# 2      2.348143  0.000000  0.509923
# 3      0.000203  2.325738  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.348143  0.000203
# 2         0.494464  0.000000  2.325738
# 3         0.407606  0.509923  0.000000
# ==================================================
# Kinetic coefficient: 1050
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661185
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.310881  0.407606
# 2      2.348143  0.000000  0.509923
# 3      0.000203  2.509321  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.348143  0.000203
# 2         0.310881  0.000000  2.509321
# 3         0.407606  0.509923  0.000000
# ==================================================
# Kinetic coefficient: 1100
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661162
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.127298  0.407606
# 2      2.348143  0.000000  0.509923
# 3      0.000203  2.692905  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.348143  0.000203
# 2         0.127298  0.000000  2.692905
# 3         0.407606  0.509923  0.000000
# ==================================================
# Kinetic coefficient: 1150
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.0931685159666116
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.068854  0.371927
# 2      2.348143  0.000000  0.509923
# 3      0.000203  2.751349  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.348143  0.000203
# 2         0.068854  0.000000  2.751349
# 3         0.371927  0.509923  0.000000
# ==================================================
# Kinetic coefficient: 1200
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661124
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.068854  0.368134
# 2      2.348132  0.000000  0.509923
# 3      0.000215  2.921628  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.348132  0.000215
# 2         0.068854  0.000000  2.921628
# 3         0.368134  0.509923  0.000000
# ==================================================
# Kinetic coefficient: 1250
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661097
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.068854  0.124986
# 2      2.354656  0.000000  0.753070
# 3      0.000213  3.105211  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.354656  0.000213
# 2         0.068854  0.000000  3.105211
# 3         0.124986  0.753070  0.000000
# ==================================================
# Kinetic coefficient: 1300
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.0931685159666113
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.040787  0.017822
# 2      2.354656  0.000000  0.774341
# 3      0.030475  3.120350  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.354656  0.030475
# 2         0.040787  0.000000  3.120350
# 3         0.017822  0.774341  0.000000
# ==================================================
# Kinetic coefficient: 1350
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.09316851596661108
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.040787  0.017822
# 2      2.354656  0.000000  0.774341
# 3      0.214058  3.120350  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.354656  0.214058
# 2         0.040787  0.000000  3.120350
# 3         0.017822  0.774341  0.000000

# %% [markdown]
# ### variable abundances

# %%
modelInfo = ["electro.community.edited.v2",93204]
mediaInfo = ["CO2_minimal",93204]
model = kbase.get_from_ws(modelInfo[0],modelInfo[1])
media = kbase.get_from_ws(mediaInfo[0],mediaInfo[1])
kinetic_coeff = 2000

# evaluate the influence of kinetic constraints over a range of coefficients
plots = []
for abundance in range(0, 10):
    species_1 = abundance/10      # Acetobacterium
    species_2 = (1-species_1)/2   # Sulfurospirillum
    species_3 = (1-species_1)/2   # Desulfovibrio
    banner = '\n{}\nAbundance\nspecies 1:{}\tspecies 2:{}\tspecies 3:{}'.format('='*50, species_1, species_2,species_3)
    print(banner)
    
    model = kbase.get_from_ws(modelInfo[0],modelInfo[1])
    media = kbase.get_from_ws(mediaInfo[0],mediaInfo[1])
    cfba = MSCommunity(model)
    cfba.drain_fluxes(media)
    cfba.gapfill(media)
    
    cfba.constrain(media, kinetic_coeff = kinetic_coeff, abundances = {"1":species_1,"2":species_2, '3':species_3})
    solution = cfba.run()
    cfba.compute_interactions(solution)
    graph, pos, labels = cfba.visualize()
    plots.append((graph, pos, labels, banner))
# Out:
# ==================================================
# Abundance
# species 1:0.0	species 2:0.5	species 3:0.5
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.11953747828719627
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.023278  0.028063
# 2      0.270149  0.000000  0.362348
# 3      0.049207  2.756893  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  0.270149  0.049207
# 2         0.023278  0.000000  2.756893
# 3         0.028063  0.362348  0.000000
# ==================================================
# Abundance
# species 1:0.1	species 2:0.45	species 3:0.45
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.12108338884599884
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.070499  0.126111
# 2      0.285182  0.000000  0.332681
# 3      0.528736  2.530110  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  0.285182  0.528736
# 2         0.070499  0.000000  2.530110
# 3         0.126111  0.332681  0.000000
# ==================================================
# Abundance
# species 1:0.2	species 2:0.4	species 3:0.4
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.12253988864767994
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.102290  0.245074
# 2      0.564874  0.000000  0.299003
# 3      0.988325  2.351206  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  0.564874  0.988325
# 2         0.102290  0.000000  2.351206
# 3         0.245074  0.299003  0.000000
# ==================================================
# Abundance
# species 1:0.3	species 2:0.35	species 3:0.35
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.12403185525267349
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.104898  0.349023
# 2      1.072918  0.000000  0.264657
# 3      1.413024  2.193131  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  1.072918  1.413024
# 2         0.104898  0.000000  2.193131
# 3         0.349023  0.264657  0.000000
# ==================================================
# Abundance
# species 1:0.4	species 2:0.3	species 3:0.3
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.1255606000908295
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.137323  0.459304
# 2      1.649426  0.000000  0.229549
# 3      1.841448  2.031487  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  1.649426  1.841448
# 2         0.137323  0.000000  2.031487
# 3         0.459304  0.229549  0.000000
# ==================================================
# Abundance
# species 1:0.5	species 2:0.25	species 3:0.25
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.12712750005455584
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.051595  0.043557
# 2      2.324807  0.000000  0.199619
# 3      1.803409  2.151347  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  2.324807  1.803409
# 2         0.051595  0.000000  2.151347
# 3         0.043557  0.199619  0.000000
# ==================================================
# Abundance
# species 1:0.6	species 2:0.2	species 3:0.2
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.12873400163503726
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.024458  0.019502
# 2      4.219219  0.000000  0.597353
# 3      0.845437  3.339373  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  4.219219  0.845437
# 2         0.024458  0.000000  3.339373
# 3         0.019502  0.597353  0.000000
# ==================================================
# Abundance
# species 1:0.7	species 2:0.15000000000000002	species 3:0.15000000000000002
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.1303816253761052
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.014372  0.016993
# 2      5.329102  0.000000  0.451500
# 3      0.464693  3.130949  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  5.329102  0.464693
# 2         0.014372  0.000000  3.130949
# 3         0.016993  0.451500  0.000000
# ==================================================
# Abundance
# species 1:0.8	species 2:0.09999999999999998	species 3:0.09999999999999998
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.1320719706745436
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.185003  0.181412
# 2      5.873835  0.000000  0.155697
# 3      0.000257  2.500696  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  5.873835  0.000257
# 2         0.185003  0.000000  2.500696
# 3         0.181412  0.155697  0.000000
# ==================================================
# Abundance
# species 1:0.9	species 2:0.04999999999999999	species 3:0.04999999999999999
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178979
# species 2 drain-flux objective value: 0.11304811462925872
# species 3 drain-flux objective value: 0.12709584977365385
# Warning:Community biomass reaction is being altered with input abundances
# 1:bio2
# 2:bio3
# 3:bio4
#
# Model objective value: 0.13335318427544687
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.311438  0.102872
# 2      5.496429  0.000000  0.055567
# 3      0.000289  1.255594  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  5.496429  0.000289
# 2         0.311438  0.000000  1.255594
# 3         0.102872  0.055567  0.000000
