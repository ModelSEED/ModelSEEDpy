# %%
# import kbase
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path
import cobrakbase
with open("C:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase = cobrakbase.KBaseAPI(token_file.readline())
import networkx
from matplotlib import pyplot

from pandas import set_option
set_option('display.max_rows', None)

# import cFBA
# %run ../../../modelseedpy/community/mscommunity.py
# %matplotlib inline
# Out:
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
# cobrakbase 0.2.8

# %% [markdown]
# # 2-member Zahmeeth model

# %% [markdown]
# ### sans uptake constraints

# %%
modelInfo_2 = ["CMM_iAH991V2_iML1515.kb",40576]
mediaInfo_2 = ["Btheta_Ecoli_minimal_media",40576]
model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])

# simulate and visualize the model
cfba = MSCommunity(model)
cfba.drain_fluxes(media)
cfba.gapfill(media)
cfba.constrain(media)
solution = cfba.run()
cfba.compute_interactions(solution)
cfba.visualize()
# Out:
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
#
# Model objective value: 0.1737502402900215
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000
# (<networkx.classes.graph.Graph at 0x7f792dbf2bb0>,
#  {1: array([1.00000000e+00, 4.37113883e-08]),
#   2: array([-1.00000000e+00, -4.37113883e-08])},
#  {(1, 2): '-409'})

# %% [markdown]
# ### variable carbon uptake

# %%
modelInfo_2 = ["CMM_iAH991V2_iML1515.kb",40576]
mediaInfo_2 = ["Btheta_Ecoli_minimal_media",40576]

org_model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
uptake = {}

# evaluate the influence of kinetic constraints over a range of coefficients
plots = []
for carbon_limit in range(0,60,10):
    uptake['C'] = carbon_limit
    banner = '\n{}\nCarbon uptake limit: {}'.format('='*50, carbon_limit)
    print(banner)
    
    model = org_model.copy()
    cfba = MSCommunity(model)
    cfba.gapfill(media)
    cfba.constrain(uptake)
    cfba.run(media)
    cross_feeding, exMets = cfba.compute_interactions(threshold=.1, filename=f"CUptake_{carbon_limit}.svg")
    display(cross_feeding)
    display(exMets)
# Out:
# ==================================================
# Carbon uptake limit: 0
# cpd11416_c0
# bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# primary biomass defined bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 -->
# cpd11416_c1
# cpd11416_c2
# cpd11416_c1
# c1
# cpd11416_c2
# c2
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\cobra\core\metabolite.py:129: UserWarning: invalid character '*' found in form
# cpd00117_e0          0.000000e+00  0.000000e+00 -2.168404e-19
# cpd00118_e0          0.000000e+00  4.055331e-04 -4.055331e-04
# cpd00119_e0          0.000000e+00  8.046634e-03 -8.046634e-03
# cpd00129_e0          0.000000e+00 -1.920418e-02  1.920418e-02
# cpd00132_e0          0.000000e+00 -2.094168e-02  2.094168e-02
# cpd00149_e0          4.077049e-04 -2.171878e-06 -4.055331e-04
# cpd00161_e0          0.000000e+00 -7.076847e-03  7.076847e-03
# cpd00182_e0          0.000000e+00  2.350667e-03 -2.350667e-03
# cpd00205_e0          1.736295e-02 -1.695742e-02 -4.055331e-04
# cpd00214_e0          0.000000e+00 -4.930381e-32  0.000000e+00
# cpd00221_e0          0.000000e+00  2.478086e+00 -2.478086e+00
# cpd00239_e0          4.423160e-02  0.000000e+00 -4.423160e-02
# cpd00244_e0          2.806066e-05 -2.806066e-05  0.000000e+00
# cpd00249_e0          0.000000e+00  2.876956e-02 -2.876956e-02
# cpd00254_e0          1.159175e-03 -7.536417e-04 -4.055331e-04
# cpd00305_e0          0.000000e+00 -1.937315e-05  1.937315e-05
# cpd00322_e0          0.000000e+00 -2.523974e-02  2.523974e-02
# cpd00363_e0          0.000000e+00  2.850460e-02 -2.850460e-02
# cpd00635_e0          4.055331e-04  0.000000e+00 -4.055331e-04
# cpd00644_e0          0.000000e+00 -5.855383e-05  5.855383e-05
# cpd00971_e0          4.055331e-04  5.421011e-20 -4.055331e-04
# cpd03586_e0          0.000000e+00  1.690242e-03  0.000000e+00
# cpd10515_e0          1.122513e-03 -7.169804e-04 -4.055331e-04
# cpd10516_e0          1.083854e-03 -6.783209e-04 -4.055331e-04
# cpd11574_e0          6.081258e-07 -6.081258e-07  0.000000e+00
# cpd11640_e0         -7.858907e+00  5.781746e+00  2.077161e+00
# cpd15432_e0         -4.930381e-32  4.930381e-32  0.000000e+00
# cps_bt_e0            0.000000e+00  0.000000e+00  4.055331e-04
# lps_bt_e0            0.000000e+00  0.000000e+00  1.689721e-03
# pe_cer1_bt_e0        0.000000e+00  0.000000e+00  4.055331e-04
# sphmyln_bt_e0        0.000000e+00  0.000000e+00  4.055331e-04
# zzEnvironment        0.000000e+00  2.044444e+00  5.196018e+00
# zzSpecies1           1.687949e+01  0.000000e+00  9.876096e+00
# zzSpecies2           1.463750e+01  5.605426e+00  0.000000e+00
#                         Environment            Species1  \
# Donor ID
# Environment                              D-Glucose; NH3
# Species1       H2; Acetate; CO2; H+
# Species2     H2; Succinate; H2O; H+  D-Lactate; Acetate
#
#                               Species2
# Donor ID
# Environment  Phosphate; D-Glucose; NH3
# Species1         L-Aspartate; Pyruvate
# Species2

# %% [markdown]
# ### variable elemental uptakes

# %%
modelInfo_2 = ["CMM_iAH991V2_iML1515.kb",40576]
mediaInfo_2 = ["Btheta_Ecoli_minimal_media",40576]
model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
uptake = {}

# evaluate the influence of kinetic constraints over a range of coefficients
plots = []
for element in ['C', 'P']:
    uptake[element] = 60
    banner = '\n{}\n{} uptake limit: {}'.format('='*50, element, uptake[element])
    print(banner)
    
    model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
    media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
    cfba = MSCommunity(model)
    cfba.drain_fluxes(media)
    cfba.gapfill(media)
    
    cfba.constrain(media, element_uptake_limit = uptake)
    solution = cfba.run()
    cfba.compute_interactions(solution)
    graph, pos, labels = cfba.visualize()
    plots.append((graph, pos, labels, banner))
# Out:
# ==================================================
# C uptake limit: 60
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.17375024029002173
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000
# ==================================================
# P uptake limit: 60
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.1737502402900212
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000

# %% [markdown]
# # 3-member Electrosynth model

# %% [markdown]
# ### sans uptake constraints

# %%
modelInfo = ["electro.community.edited.v2",93204]
mediaInfo = ["CO2_minimal",93204]
model = kbase.get_from_ws(modelInfo[0],modelInfo[1])
media = kbase.get_from_ws(mediaInfo[0],mediaInfo[1])

# simulate and visualize the model
cfba = MSCommunity(model)
cfba.drain_fluxes(media)
cfba.gapfill(media)
cfba.constrain(media)
solution = cfba.run()
cfba.compute_interactions(solution)
cfba.visualize()
# Out:
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# Making biomass drain: cpd11416_c3
# species 1 drain-flux objective value: 0.1339023910178982
# species 2 drain-flux objective value: 0.11304811462925908
# species 3 drain-flux objective value: 0.12709584977365426
#
# Model objective value: 0.12453728378574261
#
#
#
# Production matrix:
#               1         2         3
# Donor
# 1      0.000000  0.112128  0.382651
# 2      1.256793  0.000000  0.252692
# 3      1.554661  2.139689  0.000000
#
#
# Consumption matrix:
#                  1         2         3
# Receiver
# 1         0.000000  1.256793  1.554661
# 2         0.112128  0.000000  2.139689
# 3         0.382651  0.252692  0.000000
# (<networkx.classes.graph.Graph at 0x7f7907179280>,
#  {1: array([1.00000000e+00, 1.98682151e-08]),
#   2: array([-0.50000007,  0.86602542]),
#   3: array([-0.49999993, -0.86602544])},
#  {(1, 2): '-1.14', (1, 3): '-1.17', (2, 3): '-1.89'})

# %% [markdown]
# ### variable carbon uptake

# %%
modelInfo = ["electro.community.edited.v2",93204]
mediaInfo = ["CO2_minimal",93204]
model = kbase.get_from_ws(modelInfo[0],modelInfo[1])
media = kbase.get_from_ws(mediaInfo[0],mediaInfo[1])
uptake = {}

# evaluate the influence of kinetic constraints over a range of coefficients
plots = []
for carbon_limit in range(0,60,10):
    uptake['C'] = carbon_limit
    banner = '\n{}\nCarbon uptake limit: {}'.format('='*50, carbon_limit)
    print(banner)
    
    model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
    media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
    cfba = MSCommunity(model)
    cfba.drain_fluxes(media)
    cfba.gapfill(media)
    
    cfba.constrain(media, element_uptake_limit = uptake)
    solution = cfba.run()
    cfba.compute_interactions(solution)
    graph, pos, labels = cfba.visualize()
    plots.append((graph, pos, labels, banner))
# Out:
# ==================================================
# Carbon uptake limit: 0
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.0
#
#
#
# Production matrix:
#          1    2
# Donor
# 1      0.0  0.0
# 2      0.0  0.0
#
#
# Consumption matrix:
#             1    2
# Receiver
# 1         0.0  0.0
# 2         0.0  0.0
# ==================================================
# Carbon uptake limit: 10
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.057837781150852884
#
#
#
# Production matrix:
#                 1         2
# Donor
# 1        0.000000  6.079939
# 2      142.093468  0.000000
#
#
# Consumption matrix:
#                  1           2
# Receiver
# 1         0.000000  142.093468
# 2         6.079939    0.000000
# ==================================================
# Carbon uptake limit: 20
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.1156755623017053
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  12.159877
# 2      284.186935   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  284.186935
# 2         12.159877    0.000000
# ==================================================
# Carbon uptake limit: 30
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.1735133434525585
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.239816
# 2      426.280403   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.280403
# 2         18.239816    0.000000
# ==================================================
# Carbon uptake limit: 40
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.17375024029002173
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000
# ==================================================
# Carbon uptake limit: 50
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.17375024029002173
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000

# %% [markdown]
# ### variable elemental uptakes

# %%
modelInfo = ["electro.community.edited.v2",93204]
mediaInfo = ["CO2_minimal",93204]
model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
uptake = {}

# evaluate the influence of kinetic constraints over a range of coefficients
plots = []
for element in ['C', 'P']:
    uptake[element] = 60
    banner = '\n{}\n{} uptake limit: {}'.format('='*50, element, uptake[element])
    print(banner)
    
    model = kbase.get_from_ws(modelInfo_2[0],modelInfo_2[1])
    media = kbase.get_from_ws(mediaInfo_2[0],mediaInfo_2[1])
    cfba = MSCommunity(model)
    cfba.drain_fluxes(media)
    cfba.gapfill(media)
    
    cfba.constrain(media, element_uptake_limit = uptake)
    solution = cfba.run()
    cfba.compute_interactions(solution)
    graph, pos, labels = cfba.visualize()
    plots.append((graph, pos, labels, banner))
# Out:
# ==================================================
# C uptake limit: 60
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.17375024029002173
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000
# ==================================================
# P uptake limit: 60
# Making biomass drain: cpd11416_c1
# Making biomass drain: cpd11416_c2
# species 1 drain-flux objective value: 0.17439698835991793
# species 2 drain-flux objective value: 0.16925387417839624
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula '*'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# /usr/local/lib/python3.8/dist-packages/cobra/core/metabolite.py:86: UserWarning: invalid character '*' found in formula 'C12H20O10*2'
#   warn("invalid character '*' found in formula '%s'" % self.formula)
# Model objective value: 0.1737502402900212
#
#
#
# Production matrix:
#                 1          2
# Donor
# 1        0.000000  18.264719
# 2      426.862401   0.000000
#
#
# Consumption matrix:
#                   1           2
# Receiver
# 1          0.000000  426.862401
# 2         18.264719    0.000000
